# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (1.15.2)
# Requirement already satisfied: joblib>=0.12 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.14.0)
# Requirement already satisfied: numba>=0.38.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.38.1)
# Requirement already satisfied: decorator>=3.0.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (4.3.0)
# Requirement already satisfied: audioread>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (2.1.8)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: soundfile>=0.9.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.10.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.19.2)
# Requirement already satisfied: resampy>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: six>=1.3 in /opt/conda/lib/python3.6/site-packages (from librosa) (1.11.0)
# Requirement already satisfied: llvmlite>=0.23.0dev0 in /opt/conda/lib/python3.6/site-packages (from numba>=0.38.0->librosa) (0.23.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.6/site-packages (from soundfile>=0.9.0->librosa) (1.11.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.18)

# %%
import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

import os
import keras
import h5py
import librosa
import itertools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
from collections import OrderedDict

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Input
from keras.layers import Dropout
from keras.models import Model
from keras.applications.vgg16 import VGG16
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Read the data
#
# > Helper functions to assist the process to read songs, split then and return an array of spectrograms/melspectrograms

# %%
"""
@description: Method to split a song into multiple songs using overlapping windows
"""
def splitsongs(X, y, window = 0.1, overlap = 0.5):
    # Empty lists to hold our results
    temp_X = []
    temp_y = []

    # Get the input song array size
    xshape = X.shape[0]
    chunk = int(xshape*window)
    offset = int(chunk*(1.-overlap))
    
    # Split the song and create new ones on windows
    spsong = [X[i:i+chunk] for i in range(0, xshape - chunk + offset, offset)]
    for s in spsong:
        temp_X.append(s)
        temp_y.append(y)

    return np.array(temp_X), np.array(temp_y)

# %%
"""
@description: Method to convert a list of songs to a np array of melspectrograms
"""
def to_melspectrogram(songs, n_fft = 1024, hop_length = 512):
    # Transformation function
    melspec = lambda x: librosa.feature.melspectrogram(x, n_fft = n_fft,
        hop_length = hop_length)[:,:,np.newaxis]

    # map transformation of input songs to melspectrogram using log-scale
    tsongs = map(melspec, songs)
    return np.array(list(tsongs))

# %%
def read_data(src_dir, genres, song_samples, spec_format, debug = True):    
    # Empty array of dicts with the processed features from all files
    arr_specs = []
    arr_genres = []

    # Read files from the folders
    for x,_ in genres.items():
        folder = src_dir + x
        print(folder)
        for root, subdirs, files in os.walk(folder):
            for file in files:
                # Read the audio file
                file_name = folder + "/" + file
                print(file_name)
                signal, sr = librosa.load(file_name)
                signal = signal[:song_samples]
                
                # Debug process
                if debug:
                    print("Reading file: {}".format(file_name))
                
                # Convert to dataset of spectograms/melspectograms
                signals, y = splitsongs(signal, genres[x])
                
                # Convert to "spec" representation
                specs = spec_format(signals)
                
                # Save files
                arr_genres.extend(y)
                arr_specs.extend(specs)
                
                
    return np.array(arr_specs), np.array(arr_genres)

# %%
# # Parameters
# gtzan_dir = './GTZAN/genres/training_set/'
# song_samples = 660000
# genres = {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4,
#           'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
# Parameters
gtzan_dir = './GTZAN/genres/training_set/'
song_samples = 660000
genres = {'blues': 0, 'classical': 1, 'hiphop': 2, 'jazz': 3, 'disco':4, 'rock':5}

# %%
# Read the data
X, y = read_data(gtzan_dir, genres, song_samples, to_melspectrogram, debug=False)
np.save('x_gtzan_npy.npy', X)
np.save('y_gtzan_npy.npy', y)
# Out:
# ./GTZAN/genres/training_set/blues
# ./GTZAN/genres/training_set/blues/blues.00020.au
# ./GTZAN/genres/training_set/blues/blues.00080.au
# ./GTZAN/genres/training_set/blues/blues.00077.au
# ./GTZAN/genres/training_set/blues/blues.00015.au
# ./GTZAN/genres/training_set/blues/blues.00076.au
# ./GTZAN/genres/training_set/blues/blues.00065.au
# ./GTZAN/genres/training_set/blues/blues.00033.au
# ./GTZAN/genres/training_set/blues/blues.00075.au
# ./GTZAN/genres/training_set/blues/blues.00006.au
# ./GTZAN/genres/training_set/blues/blues.00081.au
# ./GTZAN/genres/training_set/blues/blues.00054.au
# ./GTZAN/genres/training_set/blues/blues.00051.au
# ./GTZAN/genres/training_set/blues/blues.00086.au
# ./GTZAN/genres/training_set/blues/blues.00089.au
# ./GTZAN/genres/training_set/blues/blues.00028.au
# ./GTZAN/genres/training_set/blues/blues.00085.au
# ./GTZAN/genres/training_set/blues/blues.00078.au
# ./GTZAN/genres/training_set/blues/blues.00043.au
# ./GTZAN/genres/training_set/blues/blues.00019.au
# ./GTZAN/genres/training_set/blues/blues.00036.au
# ./GTZAN/genres/training_set/blues/blues.00024.au
# ./GTZAN/genres/training_set/blues/blues.00040.au
# ./GTZAN/genres/training_set/blues/blues.00001.au
# ./GTZAN/genres/training_set/blues/blues.00017.au
# ./GTZAN/genres/training_set/blues/blues.00074.au
# ./GTZAN/genres/training_set/blues/blues.00056.au
# ./GTZAN/genres/training_set/blues/blues.00049.au
# ./GTZAN/genres/training_set/blues/blues.00084.au
# ./GTZAN/genres/training_set/blues/blues.00046.au
# ./GTZAN/genres/training_set/blues/blues.00044.au
# ./GTZAN/genres/training_set/blues/blues.00004.au
# ./GTZAN/genres/training_set/blues/blues.00045.au
# ./GTZAN/genres/training_set/blues/blues.00026.au
# ./GTZAN/genres/training_set/blues/blues.00041.au
# ./GTZAN/genres/training_set/blues/blues.00030.au
# ./GTZAN/genres/training_set/blues/blues.00069.au
# ./GTZAN/genres/training_set/blues/blues.00072.au
# ./GTZAN/genres/training_set/blues/blues.00087.au
# ./GTZAN/genres/training_set/blues/blues.00005.au
# ./GTZAN/genres/training_set/blues/blues.00079.au
# ./GTZAN/genres/training_set/blues/blues.00014.au
# ./GTZAN/genres/training_set/blues/blues.00000.au
# ./GTZAN/genres/training_set/blues/blues.00037.au
# ./GTZAN/genres/training_set/blues/blues.00003.au
# ./GTZAN/genres/training_set/blues/blues.00010.au
# ./GTZAN/genres/training_set/blues/blues.00048.au
# ./GTZAN/genres/training_set/blues/blues.00034.au
# ./GTZAN/genres/training_set/blues/blues.00035.au
# ./GTZAN/genres/training_set/blues/blues.00050.au
# ./GTZAN/genres/training_set/blues/blues.00023.au
# ./GTZAN/genres/training_set/blues/blues.00039.au
# ./GTZAN/genres/training_set/blues/blues.00047.au
# ./GTZAN/genres/training_set/blues/blues.00029.au
# ./GTZAN/genres/training_set/blues/blues.00007.au
# ./GTZAN/genres/training_set/blues/blues.00002.au
# ./GTZAN/genres/training_set/blues/blues.00053.au
# ./GTZAN/genres/training_set/blues/blues.00038.au
# ./GTZAN/genres/training_set/blues/blues.00016.au
# ./GTZAN/genres/training_set/blues/blues.00067.au
# ./GTZAN/genres/training_set/blues/blues.00068.au
# ./GTZAN/genres/training_set/blues/blues.00042.au
# ./GTZAN/genres/training_set/blues/blues.00063.au
# ./GTZAN/genres/training_set/blues/blues.00071.au
# ./GTZAN/genres/training_set/blues/blues.00059.au
# ./GTZAN/genres/training_set/blues/blues.00013.au
# ./GTZAN/genres/training_set/blues/blues.00052.au
# ./GTZAN/genres/training_set/blues/blues.00060.au
# ./GTZAN/genres/training_set/blues/blues.00062.au
# ./GTZAN/genres/training_set/blues/blues.00011.au
# ./GTZAN/genres/training_set/blues/blues.00008.au
# ./GTZAN/genres/training_set/blues/blues.00031.au
# ./GTZAN/genres/training_set/blues/blues.00061.au
# ./GTZAN/genres/training_set/blues/blues.00022.au
# ./GTZAN/genres/training_set/blues/blues.00012.au
# ./GTZAN/genres/training_set/blues/blues.00025.au
# ./GTZAN/genres/training_set/blues/blues.00088.au
# ./GTZAN/genres/training_set/blues/blues.00082.au
# ./GTZAN/genres/training_set/blues/blues.00073.au
# ./GTZAN/genres/training_set/blues/blues.00057.au
# ./GTZAN/genres/training_set/blues/blues.00058.au
# ./GTZAN/genres/training_set/blues/blues.00032.au
# ./GTZAN/genres/training_set/blues/blues.00027.au
# ./GTZAN/genres/training_set/blues/blues.00021.au
# ./GTZAN/genres/training_set/blues/blues.00064.au
# ./GTZAN/genres/training_set/blues/blues.00055.au
# ./GTZAN/genres/training_set/blues/blues.00066.au
# ./GTZAN/genres/training_set/blues/blues.00018.au
# ./GTZAN/genres/training_set/blues/blues.00083.au
# ./GTZAN/genres/training_set/blues/blues.00070.au
# ./GTZAN/genres/training_set/blues/blues.00009.au
# ./GTZAN/genres/training_set/classical
# ./GTZAN/genres/training_set/classical/classical.00034.au
# ./GTZAN/genres/training_set/classical/classical.00005.au
# ./GTZAN/genres/training_set/classical/classical.00055.au
# ./GTZAN/genres/training_set/classical/classical.00063.au
# ./GTZAN/genres/training_set/classical/classical.00068.au
# ./GTZAN/genres/training_set/classical/classical.00042.au
# ./GTZAN/genres/training_set/classical/classical.00022.au
# ./GTZAN/genres/training_set/classical/classical.00013.au
# ./GTZAN/genres/training_set/classical/classical.00060.au
# ./GTZAN/genres/training_set/classical/classical.00029.au
# ./GTZAN/genres/training_set/classical/classical.00014.au
# ./GTZAN/genres/training_set/classical/classical.00020.au
# ./GTZAN/genres/training_set/classical/classical.00001.au
# ./GTZAN/genres/training_set/classical/classical.00052.au
# ./GTZAN/genres/training_set/classical/classical.00011.au
# ./GTZAN/genres/training_set/classical/classical.00004.au
# ./GTZAN/genres/training_set/classical/classical.00048.au
# ./GTZAN/genres/training_set/classical/classical.00019.au
# ./GTZAN/genres/training_set/classical/classical.00074.au
# ./GTZAN/genres/training_set/classical/classical.00054.au
# ./GTZAN/genres/training_set/classical/classical.00082.au
# ./GTZAN/genres/training_set/classical/classical.00044.au
# ./GTZAN/genres/training_set/classical/classical.00051.au
# ./GTZAN/genres/training_set/classical/classical.00033.au
# ./GTZAN/genres/training_set/classical/classical.00056.au
# ./GTZAN/genres/training_set/classical/classical.00066.au
# ./GTZAN/genres/training_set/classical/classical.00028.au
# ./GTZAN/genres/training_set/classical/classical.00040.au
# ./GTZAN/genres/training_set/classical/classical.00041.au
# ./GTZAN/genres/training_set/classical/classical.00003.au
# ./GTZAN/genres/training_set/classical/classical.00031.au
# ./GTZAN/genres/training_set/classical/classical.00043.au
# ./GTZAN/genres/training_set/classical/classical.00087.au
# ./GTZAN/genres/training_set/classical/classical.00077.au
# ./GTZAN/genres/training_set/classical/classical.00035.au
# ./GTZAN/genres/training_set/classical/classical.00073.au
# ./GTZAN/genres/training_set/classical/classical.00038.au
# ./GTZAN/genres/training_set/classical/classical.00008.au
# ./GTZAN/genres/training_set/classical/classical.00010.au
# ./GTZAN/genres/training_set/classical/classical.00059.au
# ./GTZAN/genres/training_set/classical/classical.00018.au
# ./GTZAN/genres/training_set/classical/classical.00076.au
# ./GTZAN/genres/training_set/classical/classical.00039.au
# ./GTZAN/genres/training_set/classical/classical.00064.au
# ./GTZAN/genres/training_set/classical/classical.00086.au
# ./GTZAN/genres/training_set/classical/classical.00053.au
# ./GTZAN/genres/training_set/classical/classical.00081.au
# ./GTZAN/genres/training_set/classical/classical.00067.au
# ./GTZAN/genres/training_set/classical/classical.00050.au
# ./GTZAN/genres/training_set/classical/classical.00030.au
# ./GTZAN/genres/training_set/classical/classical.00085.au
# ./GTZAN/genres/training_set/classical/classical.00069.au
# ./GTZAN/genres/training_set/classical/classical.00072.au
# ./GTZAN/genres/training_set/classical/classical.00049.au
# ./GTZAN/genres/training_set/classical/classical.00017.au
# ./GTZAN/genres/training_set/classical/classical.00061.au
# ./GTZAN/genres/training_set/classical/classical.00021.au
# ./GTZAN/genres/training_set/classical/classical.00075.au
# ./GTZAN/genres/training_set/classical/classical.00027.au
# ./GTZAN/genres/training_set/classical/classical.00009.au
# ./GTZAN/genres/training_set/classical/classical.00089.au
# ./GTZAN/genres/training_set/classical/classical.00080.au
# ./GTZAN/genres/training_set/classical/classical.00006.au
# ./GTZAN/genres/training_set/classical/classical.00002.au
# ./GTZAN/genres/training_set/classical/classical.00007.au
# ./GTZAN/genres/training_set/classical/classical.00088.au
# ./GTZAN/genres/training_set/classical/classical.00000.au
# ./GTZAN/genres/training_set/classical/classical.00025.au
# ./GTZAN/genres/training_set/classical/classical.00084.au
# ./GTZAN/genres/training_set/classical/classical.00046.au
# ./GTZAN/genres/training_set/classical/classical.00024.au
# ./GTZAN/genres/training_set/classical/classical.00079.au
# ./GTZAN/genres/training_set/classical/classical.00047.au
# ./GTZAN/genres/training_set/classical/classical.00015.au
# ./GTZAN/genres/training_set/classical/classical.00062.au
# ./GTZAN/genres/training_set/classical/classical.00083.au
# ./GTZAN/genres/training_set/classical/classical.00023.au
# ./GTZAN/genres/training_set/classical/classical.00036.au
# ./GTZAN/genres/training_set/classical/classical.00078.au
# ./GTZAN/genres/training_set/classical/classical.00045.au
# ./GTZAN/genres/training_set/classical/classical.00026.au
# ./GTZAN/genres/training_set/classical/classical.00057.au
# ./GTZAN/genres/training_set/classical/classical.00071.au
# ./GTZAN/genres/training_set/classical/classical.00070.au
# ./GTZAN/genres/training_set/classical/classical.00032.au
# ./GTZAN/genres/training_set/classical/classical.00037.au
# ./GTZAN/genres/training_set/classical/classical.00058.au
# ./GTZAN/genres/training_set/classical/classical.00012.au
# ./GTZAN/genres/training_set/classical/classical.00016.au
# ./GTZAN/genres/training_set/classical/classical.00065.au
# ./GTZAN/genres/training_set/hiphop
# ./GTZAN/genres/training_set/hiphop/hiphop.00015.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00004.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00065.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00010.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00019.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00080.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00002.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00069.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00024.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00017.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00042.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00063.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00020.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00075.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00008.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00054.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00082.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00088.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00087.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00059.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00047.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00066.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00055.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00021.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00018.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00085.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00030.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00050.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00043.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00053.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00041.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00089.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00061.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00034.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00071.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00064.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00035.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00086.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00028.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00032.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00027.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00000.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00007.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00070.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00005.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00040.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00044.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00067.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00077.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00081.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00057.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00037.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00009.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00006.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00025.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00033.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00026.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00068.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00023.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00022.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00076.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00039.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00052.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00049.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00048.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00051.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00001.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00014.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00031.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00062.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00058.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00013.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00036.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00072.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00003.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00083.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00046.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00038.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00079.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00060.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00074.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00012.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00056.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00078.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00016.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00029.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00084.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00045.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00011.au
# ./GTZAN/genres/training_set/hiphop/hiphop.00073.au
# ./GTZAN/genres/training_set/jazz
# ./GTZAN/genres/training_set/jazz/jazz.00011.au
# ./GTZAN/genres/training_set/jazz/jazz.00010.au
# ./GTZAN/genres/training_set/jazz/jazz.00079.au
# ./GTZAN/genres/training_set/jazz/jazz.00058.au
# ./GTZAN/genres/training_set/jazz/jazz.00065.au
# ./GTZAN/genres/training_set/jazz/jazz.00084.au
# ./GTZAN/genres/training_set/jazz/jazz.00017.au
# ./GTZAN/genres/training_set/jazz/jazz.00031.au
# ./GTZAN/genres/training_set/jazz/jazz.00020.au
# ./GTZAN/genres/training_set/jazz/jazz.00006.au
# ./GTZAN/genres/training_set/jazz/jazz.00042.au
# ./GTZAN/genres/training_set/jazz/jazz.00002.au
# ./GTZAN/genres/training_set/jazz/jazz.00056.au
# ./GTZAN/genres/training_set/jazz/jazz.00008.au
# ./GTZAN/genres/training_set/jazz/jazz.00047.au
# ./GTZAN/genres/training_set/jazz/jazz.00045.au
# ./GTZAN/genres/training_set/jazz/jazz.00012.au
# ./GTZAN/genres/training_set/jazz/jazz.00038.au
# ./GTZAN/genres/training_set/jazz/jazz.00040.au
# ./GTZAN/genres/training_set/jazz/jazz.00029.au
# ./GTZAN/genres/training_set/jazz/jazz.00030.au
# ./GTZAN/genres/training_set/jazz/jazz.00018.au
# ./GTZAN/genres/training_set/jazz/jazz.00044.au
# ./GTZAN/genres/training_set/jazz/jazz.00027.au
# ./GTZAN/genres/training_set/jazz/jazz.00037.au
# ./GTZAN/genres/training_set/jazz/jazz.00013.au
# ./GTZAN/genres/training_set/jazz/jazz.00068.au
# ./GTZAN/genres/training_set/jazz/jazz.00052.au
# ./GTZAN/genres/training_set/jazz/jazz.00069.au
# ./GTZAN/genres/training_set/jazz/jazz.00023.au
# ./GTZAN/genres/training_set/jazz/jazz.00071.au
# ./GTZAN/genres/training_set/jazz/jazz.00054.au
# ./GTZAN/genres/training_set/jazz/jazz.00080.au
# ./GTZAN/genres/training_set/jazz/jazz.00036.au
# ./GTZAN/genres/training_set/jazz/jazz.00086.au
# ./GTZAN/genres/training_set/jazz/jazz.00087.au
# ./GTZAN/genres/training_set/jazz/jazz.00014.au
# ./GTZAN/genres/training_set/jazz/jazz.00024.au
# ./GTZAN/genres/training_set/jazz/jazz.00049.au
# ./GTZAN/genres/training_set/jazz/jazz.00055.au
# ./GTZAN/genres/training_set/jazz/jazz.00046.au
# ./GTZAN/genres/training_set/jazz/jazz.00081.au
# ./GTZAN/genres/training_set/jazz/jazz.00022.au
# ./GTZAN/genres/training_set/jazz/jazz.00035.au
# ./GTZAN/genres/training_set/jazz/jazz.00001.au
# ./GTZAN/genres/training_set/jazz/jazz.00067.au
# ./GTZAN/genres/training_set/jazz/jazz.00041.au
# ./GTZAN/genres/training_set/jazz/jazz.00053.au
# ./GTZAN/genres/training_set/jazz/jazz.00088.au
# ./GTZAN/genres/training_set/jazz/jazz.00004.au
# ./GTZAN/genres/training_set/jazz/jazz.00089.au
# ./GTZAN/genres/training_set/jazz/jazz.00082.au
# ./GTZAN/genres/training_set/jazz/jazz.00057.au
# ./GTZAN/genres/training_set/jazz/jazz.00078.au
# ./GTZAN/genres/training_set/jazz/jazz.00075.au
# ./GTZAN/genres/training_set/jazz/jazz.00062.au
# ./GTZAN/genres/training_set/jazz/jazz.00026.au
# ./GTZAN/genres/training_set/jazz/jazz.00032.au
# ./GTZAN/genres/training_set/jazz/jazz.00007.au
# ./GTZAN/genres/training_set/jazz/jazz.00083.au
# ./GTZAN/genres/training_set/jazz/jazz.00034.au
# ./GTZAN/genres/training_set/jazz/jazz.00003.au
# ./GTZAN/genres/training_set/jazz/jazz.00039.au
# ./GTZAN/genres/training_set/jazz/jazz.00016.au
# ./GTZAN/genres/training_set/jazz/jazz.00028.au
# ./GTZAN/genres/training_set/jazz/jazz.00072.au
# ./GTZAN/genres/training_set/jazz/jazz.00064.au
# ./GTZAN/genres/training_set/jazz/jazz.00066.au
# ./GTZAN/genres/training_set/jazz/jazz.00085.au
# ./GTZAN/genres/training_set/jazz/jazz.00043.au
# ./GTZAN/genres/training_set/jazz/jazz.00005.au
# ./GTZAN/genres/training_set/jazz/jazz.00019.au
# ./GTZAN/genres/training_set/jazz/jazz.00076.au
# ./GTZAN/genres/training_set/jazz/jazz.00074.au
# ./GTZAN/genres/training_set/jazz/jazz.00077.au
# ./GTZAN/genres/training_set/jazz/jazz.00000.au
# ./GTZAN/genres/training_set/jazz/jazz.00050.au
# ./GTZAN/genres/training_set/jazz/jazz.00021.au
# ./GTZAN/genres/training_set/jazz/jazz.00025.au
# ./GTZAN/genres/training_set/jazz/jazz.00070.au
# ./GTZAN/genres/training_set/jazz/jazz.00073.au
# ./GTZAN/genres/training_set/jazz/jazz.00033.au
# ./GTZAN/genres/training_set/jazz/jazz.00009.au
# ./GTZAN/genres/training_set/jazz/jazz.00061.au
# ./GTZAN/genres/training_set/jazz/jazz.00059.au
# ./GTZAN/genres/training_set/jazz/jazz.00060.au
# ./GTZAN/genres/training_set/jazz/jazz.00015.au
# ./GTZAN/genres/training_set/jazz/jazz.00051.au
# ./GTZAN/genres/training_set/jazz/jazz.00048.au
# ./GTZAN/genres/training_set/jazz/jazz.00063.au
# ./GTZAN/genres/training_set/disco
# ./GTZAN/genres/training_set/disco/disco.00007.au
# ./GTZAN/genres/training_set/disco/disco.00073.au
# ./GTZAN/genres/training_set/disco/disco.00036.au
# ./GTZAN/genres/training_set/disco/disco.00084.au
# ./GTZAN/genres/training_set/disco/disco.00012.au
# ./GTZAN/genres/training_set/disco/disco.00051.au
# ./GTZAN/genres/training_set/disco/disco.00034.au
# ./GTZAN/genres/training_set/disco/disco.00071.au
# ./GTZAN/genres/training_set/disco/disco.00075.au
# ./GTZAN/genres/training_set/disco/disco.00025.au
# ./GTZAN/genres/training_set/disco/disco.00030.au
# ./GTZAN/genres/training_set/disco/disco.00065.au
# ./GTZAN/genres/training_set/disco/disco.00045.au
# ./GTZAN/genres/training_set/disco/disco.00018.au
# ./GTZAN/genres/training_set/disco/disco.00047.au
# ./GTZAN/genres/training_set/disco/disco.00052.au
# ./GTZAN/genres/training_set/disco/disco.00074.au
# ./GTZAN/genres/training_set/disco/disco.00026.au
# ./GTZAN/genres/training_set/disco/disco.00029.au
# ./GTZAN/genres/training_set/disco/disco.00066.au
# ./GTZAN/genres/training_set/disco/disco.00005.au
# ./GTZAN/genres/training_set/disco/disco.00056.au
# ./GTZAN/genres/training_set/disco/disco.00038.au
# ./GTZAN/genres/training_set/disco/disco.00009.au
# ./GTZAN/genres/training_set/disco/disco.00010.au
# ./GTZAN/genres/training_set/disco/disco.00006.au
# ./GTZAN/genres/training_set/disco/disco.00014.au
# ./GTZAN/genres/training_set/disco/disco.00022.au
# ./GTZAN/genres/training_set/disco/disco.00020.au
# ./GTZAN/genres/training_set/disco/disco.00015.au
# ./GTZAN/genres/training_set/disco/disco.00040.au
# ./GTZAN/genres/training_set/disco/disco.00004.au
# ./GTZAN/genres/training_set/disco/disco.00076.au
# ./GTZAN/genres/training_set/disco/disco.00064.au
# ./GTZAN/genres/training_set/disco/disco.00033.au
# ./GTZAN/genres/training_set/disco/disco.00035.au
# ./GTZAN/genres/training_set/disco/disco.00080.au
# ./GTZAN/genres/training_set/disco/disco.00050.au
# ./GTZAN/genres/training_set/disco/disco.00024.au
# ./GTZAN/genres/training_set/disco/disco.00023.au
# ./GTZAN/genres/training_set/disco/disco.00048.au
# ./GTZAN/genres/training_set/disco/disco.00062.au
# ./GTZAN/genres/training_set/disco/disco.00037.au
# ./GTZAN/genres/training_set/disco/disco.00032.au
# ./GTZAN/genres/training_set/disco/disco.00079.au
# ./GTZAN/genres/training_set/disco/disco.00054.au
# ./GTZAN/genres/training_set/disco/disco.00060.au
# ./GTZAN/genres/training_set/disco/disco.00069.au
# ./GTZAN/genres/training_set/disco/disco.00008.au
# ./GTZAN/genres/training_set/disco/disco.00058.au
# ./GTZAN/genres/training_set/disco/disco.00027.au
# ./GTZAN/genres/training_set/disco/disco.00001.au
# ./GTZAN/genres/training_set/disco/disco.00055.au
# ./GTZAN/genres/training_set/disco/disco.00013.au
# ./GTZAN/genres/training_set/disco/disco.00057.au
# ./GTZAN/genres/training_set/disco/disco.00039.au
# ./GTZAN/genres/training_set/disco/disco.00059.au
# ./GTZAN/genres/training_set/disco/disco.00003.au
# ./GTZAN/genres/training_set/disco/disco.00081.au
# ./GTZAN/genres/training_set/disco/disco.00042.au
# ./GTZAN/genres/training_set/disco/disco.00041.au
# ./GTZAN/genres/training_set/disco/disco.00067.au
# ./GTZAN/genres/training_set/disco/disco.00043.au
# ./GTZAN/genres/training_set/disco/disco.00072.au
# ./GTZAN/genres/training_set/disco/disco.00021.au
# ./GTZAN/genres/training_set/disco/disco.00088.au
# ./GTZAN/genres/training_set/disco/disco.00061.au
# ./GTZAN/genres/training_set/disco/disco.00053.au
# ./GTZAN/genres/training_set/disco/disco.00083.au
# ./GTZAN/genres/training_set/disco/disco.00049.au
# ./GTZAN/genres/training_set/disco/disco.00011.au
# ./GTZAN/genres/training_set/disco/disco.00019.au
# ./GTZAN/genres/training_set/disco/disco.00017.au
# ./GTZAN/genres/training_set/disco/disco.00089.au
# ./GTZAN/genres/training_set/disco/disco.00063.au
# ./GTZAN/genres/training_set/disco/disco.00016.au
# ./GTZAN/genres/training_set/disco/disco.00044.au
# ./GTZAN/genres/training_set/disco/disco.00082.au
# ./GTZAN/genres/training_set/disco/disco.00077.au
# ./GTZAN/genres/training_set/disco/disco.00086.au
# ./GTZAN/genres/training_set/disco/disco.00070.au
# ./GTZAN/genres/training_set/disco/disco.00046.au
# ./GTZAN/genres/training_set/disco/disco.00078.au
# ./GTZAN/genres/training_set/disco/disco.00031.au
# ./GTZAN/genres/training_set/disco/disco.00028.au
# ./GTZAN/genres/training_set/disco/disco.00068.au
# ./GTZAN/genres/training_set/disco/disco.00085.au
# ./GTZAN/genres/training_set/disco/disco.00087.au
# ./GTZAN/genres/training_set/disco/disco.00000.au
# ./GTZAN/genres/training_set/disco/disco.00002.au
# ./GTZAN/genres/training_set/rock
# ./GTZAN/genres/training_set/rock/rock.00001.au
# ./GTZAN/genres/training_set/rock/rock.00008.au
# ./GTZAN/genres/training_set/rock/rock.00003.au
# ./GTZAN/genres/training_set/rock/rock.00064.au
# ./GTZAN/genres/training_set/rock/rock.00068.au
# ./GTZAN/genres/training_set/rock/rock.00028.au
# ./GTZAN/genres/training_set/rock/rock.00026.au
# ./GTZAN/genres/training_set/rock/rock.00046.au
# ./GTZAN/genres/training_set/rock/rock.00043.au
# ./GTZAN/genres/training_set/rock/rock.00085.au
# ./GTZAN/genres/training_set/rock/rock.00084.au
# ./GTZAN/genres/training_set/rock/rock.00033.au
# ./GTZAN/genres/training_set/rock/rock.00074.au
# ./GTZAN/genres/training_set/rock/rock.00055.au
# ./GTZAN/genres/training_set/rock/rock.00071.au
# ./GTZAN/genres/training_set/rock/rock.00037.au
# ./GTZAN/genres/training_set/rock/rock.00061.au
# ./GTZAN/genres/training_set/rock/rock.00019.au
# ./GTZAN/genres/training_set/rock/rock.00057.au
# ./GTZAN/genres/training_set/rock/rock.00039.au
# ./GTZAN/genres/training_set/rock/rock.00053.au
# ./GTZAN/genres/training_set/rock/rock.00016.au
# ./GTZAN/genres/training_set/rock/rock.00052.au
# ./GTZAN/genres/training_set/rock/rock.00025.au
# ./GTZAN/genres/training_set/rock/rock.00067.au
# ./GTZAN/genres/training_set/rock/rock.00018.au
# ./GTZAN/genres/training_set/rock/rock.00060.au
# ./GTZAN/genres/training_set/rock/rock.00049.au
# ./GTZAN/genres/training_set/rock/rock.00011.au
# ./GTZAN/genres/training_set/rock/rock.00010.au
# ./GTZAN/genres/training_set/rock/rock.00005.au
# ./GTZAN/genres/training_set/rock/rock.00017.au
# ./GTZAN/genres/training_set/rock/rock.00009.au
# ./GTZAN/genres/training_set/rock/rock.00022.au
# ./GTZAN/genres/training_set/rock/rock.00077.au
# ./GTZAN/genres/training_set/rock/rock.00040.au
# ./GTZAN/genres/training_set/rock/rock.00030.au
# ./GTZAN/genres/training_set/rock/rock.00050.au
# ./GTZAN/genres/training_set/rock/rock.00014.au
# ./GTZAN/genres/training_set/rock/rock.00042.au
# ./GTZAN/genres/training_set/rock/rock.00080.au
# ./GTZAN/genres/training_set/rock/rock.00045.au
# ./GTZAN/genres/training_set/rock/rock.00069.au
# ./GTZAN/genres/training_set/rock/rock.00006.au
# ./GTZAN/genres/training_set/rock/rock.00087.au
# ./GTZAN/genres/training_set/rock/rock.00002.au
# ./GTZAN/genres/training_set/rock/rock.00004.au
# ./GTZAN/genres/training_set/rock/rock.00015.au
# ./GTZAN/genres/training_set/rock/rock.00029.au
# ./GTZAN/genres/training_set/rock/rock.00051.au
# ./GTZAN/genres/training_set/rock/rock.00023.au
# ./GTZAN/genres/training_set/rock/rock.00012.au
# ./GTZAN/genres/training_set/rock/rock.00062.au
# ./GTZAN/genres/training_set/rock/rock.00031.au
# ./GTZAN/genres/training_set/rock/rock.00088.au
# ./GTZAN/genres/training_set/rock/rock.00021.au
# ./GTZAN/genres/training_set/rock/rock.00075.au
# ./GTZAN/genres/training_set/rock/rock.00073.au
# ./GTZAN/genres/training_set/rock/rock.00013.au
# ./GTZAN/genres/training_set/rock/rock.00032.au
# ./GTZAN/genres/training_set/rock/rock.00078.au
# ./GTZAN/genres/training_set/rock/rock.00089.au
# ./GTZAN/genres/training_set/rock/rock.00036.au
# ./GTZAN/genres/training_set/rock/rock.00000.au
# ./GTZAN/genres/training_set/rock/rock.00056.au
# ./GTZAN/genres/training_set/rock/rock.00086.au
# ./GTZAN/genres/training_set/rock/rock.00072.au
# ./GTZAN/genres/training_set/rock/rock.00041.au
# ./GTZAN/genres/training_set/rock/rock.00034.au
# ./GTZAN/genres/training_set/rock/rock.00058.au
# ./GTZAN/genres/training_set/rock/rock.00082.au
# ./GTZAN/genres/training_set/rock/rock.00083.au
# ./GTZAN/genres/training_set/rock/rock.00063.au
# ./GTZAN/genres/training_set/rock/rock.00079.au
# ./GTZAN/genres/training_set/rock/rock.00038.au
# ./GTZAN/genres/training_set/rock/rock.00076.au
# ./GTZAN/genres/training_set/rock/rock.00066.au
# ./GTZAN/genres/training_set/rock/rock.00024.au
# ./GTZAN/genres/training_set/rock/rock.00007.au
# ./GTZAN/genres/training_set/rock/rock.00035.au
# ./GTZAN/genres/training_set/rock/rock.00048.au
# ./GTZAN/genres/training_set/rock/rock.00070.au
# ./GTZAN/genres/training_set/rock/rock.00027.au
# ./GTZAN/genres/training_set/rock/rock.00047.au
# ./GTZAN/genres/training_set/rock/rock.00065.au
# ./GTZAN/genres/training_set/rock/rock.00059.au
# ./GTZAN/genres/training_set/rock/rock.00044.au
# ./GTZAN/genres/training_set/rock/rock.00020.au
# ./GTZAN/genres/training_set/rock/rock.00054.au
# ./GTZAN/genres/training_set/rock/rock.00081.au

# %%
X = np.load('x_gtzan_npy.npy')
y = np.load('y_gtzan_npy.npy')

# %%
# One hot encoding of the labels
y = to_categorical(y)

# %% [markdown]
# # Dataset Split

# %%
X_stack = np.squeeze(np.stack((X,) * 3, -1))
X_stack.shape
# Out:
# (10260, 128, 129, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_stack, y, test_size=0.2, random_state=42, stratify = y)

# %%
# Histogram for train and test 
values, count = np.unique(np.argmax(y_train, axis=1), return_counts=True)
plt.bar(values, count)

values, count = np.unique(np.argmax(y_test, axis=1), return_counts=True)
plt.bar(values, count)
plt.show()

# %% [markdown]
# # Training

# %%
# Model Definition
input_shape = X_train[0].shape
num_genres = 6

def cnn_vgg16(input_shape, num_genres, freezed_layers):
    input_tensor = Input(shape=input_shape)
    vgg16 = VGG16(include_top=False, weights='imagenet',
                  input_tensor=input_tensor)

    top = Sequential()
    top.add(Flatten(input_shape=vgg16.output_shape[1:]))
    top.add(Dense(256, activation='relu'))
    top.add(Dropout(0.5))
    top.add(Dense(num_genres, activation='softmax'))

    model = Model(inputs=vgg16.input, outputs=top(vgg16.output))
    for layer in model.layers[:freezed_layers]:
        layer.trainable = False

    return model

model = cnn_vgg16(input_shape, num_genres, 5)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 129, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 129, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 129, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 6)                 2098950
# =================================================================
# Total params: 16,813,638
# Trainable params: 16,701,062
# Non-trainable params: 112,576
# _________________________________________________________________

# %%
model_path = './VGG16.h5'

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

batch_size = 128
epochs = 30

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

hist = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test, y_test),
          callbacks = [checkpoint, earlystop])
# Out:
# Train on 8208 samples, validate on 2052 samples
# Epoch 1/30
# 8208/8208 [==============================] - 20s 2ms/step - loss: 1.7927 - acc: 0.3735 - val_loss: 1.2437 - val_acc: 0.5117
#
# Epoch 00001: val_loss improved from inf to 1.24370, saving model to ./VGG16.h5
# Epoch 2/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 1.1936 - acc: 0.5156 - val_loss: 1.4816 - val_acc: 0.5302
#
# Epoch 00002: val_loss did not improve from 1.24370
# Epoch 3/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 1.0612 - acc: 0.5858 - val_loss: 0.8608 - val_acc: 0.6696
#
# Epoch 00003: val_loss improved from 1.24370 to 0.86076, saving model to ./VGG16.h5
# Epoch 4/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.8943 - acc: 0.6617 - val_loss: 0.8413 - val_acc: 0.6847
#
# Epoch 00004: val_loss improved from 0.86076 to 0.84130, saving model to ./VGG16.h5
# Epoch 5/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.7718 - acc: 0.7127 - val_loss: 0.7508 - val_acc: 0.7276
#
# Epoch 00005: val_loss improved from 0.84130 to 0.75079, saving model to ./VGG16.h5
# Epoch 6/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.6823 - acc: 0.7540 - val_loss: 0.6294 - val_acc: 0.7690
#
# Epoch 00006: val_loss improved from 0.75079 to 0.62942, saving model to ./VGG16.h5
# Epoch 7/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.5823 - acc: 0.7895 - val_loss: 0.6941 - val_acc: 0.7476
#
# Epoch 00007: val_loss did not improve from 0.62942
# Epoch 8/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.5156 - acc: 0.8166 - val_loss: 0.5413 - val_acc: 0.8075
#
# Epoch 00008: val_loss improved from 0.62942 to 0.54129, saving model to ./VGG16.h5
# Epoch 9/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.4625 - acc: 0.8383 - val_loss: 0.6629 - val_acc: 0.7783
#
# Epoch 00009: val_loss did not improve from 0.54129
# Epoch 10/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.4084 - acc: 0.8561 - val_loss: 0.4418 - val_acc: 0.8484
#
# Epoch 00010: val_loss improved from 0.54129 to 0.44178, saving model to ./VGG16.h5
# Epoch 11/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.3767 - acc: 0.8663 - val_loss: 0.8461 - val_acc: 0.7378
#
# Epoch 00011: val_loss did not improve from 0.44178
# Epoch 12/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.4473 - acc: 0.8437 - val_loss: 0.6073 - val_acc: 0.7987
#
# Epoch 00012: val_loss did not improve from 0.44178
# Epoch 13/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.3109 - acc: 0.8935 - val_loss: 0.4064 - val_acc: 0.8645
#
# Epoch 00013: val_loss improved from 0.44178 to 0.40638, saving model to ./VGG16.h5
# Epoch 14/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.2376 - acc: 0.9161 - val_loss: 0.3242 - val_acc: 0.8962
#
# Epoch 00014: val_loss improved from 0.40638 to 0.32416, saving model to ./VGG16.h5
# Epoch 15/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.2323 - acc: 0.9200 - val_loss: 0.2941 - val_acc: 0.9157
#
# Epoch 00015: val_loss improved from 0.32416 to 0.29409, saving model to ./VGG16.h5
# Epoch 16/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1810 - acc: 0.9394 - val_loss: 0.3723 - val_acc: 0.8840
#
# Epoch 00016: val_loss did not improve from 0.29409
# Epoch 17/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1883 - acc: 0.9358 - val_loss: 0.3846 - val_acc: 0.8923
#
# Epoch 00017: val_loss did not improve from 0.29409
# Epoch 18/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1513 - acc: 0.9491 - val_loss: 0.2563 - val_acc: 0.9211
#
# Epoch 00018: val_loss improved from 0.29409 to 0.25633, saving model to ./VGG16.h5
# Epoch 19/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1836 - acc: 0.9443 - val_loss: 0.3049 - val_acc: 0.9050
#
# Epoch 00019: val_loss did not improve from 0.25633
# Epoch 20/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1532 - acc: 0.9480 - val_loss: 0.2450 - val_acc: 0.9230
#
# Epoch 00020: val_loss improved from 0.25633 to 0.24499, saving model to ./VGG16.h5
# Epoch 21/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1418 - acc: 0.9500 - val_loss: 0.3381 - val_acc: 0.9128
#
# Epoch 00021: val_loss did not improve from 0.24499
# Epoch 22/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1349 - acc: 0.9553 - val_loss: 0.2747 - val_acc: 0.9240
#
# Epoch 00022: val_loss did not improve from 0.24499
# Epoch 23/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1271 - acc: 0.9605 - val_loss: 0.2478 - val_acc: 0.9215
#
# Epoch 00023: val_loss did not improve from 0.24499
# Epoch 24/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1672 - acc: 0.9485 - val_loss: 0.4809 - val_acc: 0.8962
#
# Epoch 00024: val_loss did not improve from 0.24499
# Epoch 25/30
# 8208/8208 [==============================] - 16s 2ms/step - loss: 0.1275 - acc: 0.9582 - val_loss: 0.2671 - val_acc: 0.9172
#
# Epoch 00025: val_loss did not improve from 0.24499
# Epoch 00025: early stopping

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("val_loss = {:.3f} and val_acc = {:.3f}".format(score[0], score[1]))
# Out:
# val_loss = 0.267 and val_acc = 0.917

# %%
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.plot(hist.history['acc'], label='train')
plt.plot(hist.history['val_acc'], label='validation')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
preds = np.argmax(model.predict(X_test), axis = 1)
y_orig = np.argmax(y_test, axis = 1)
cm = confusion_matrix(preds, y_orig)

# %%
keys = OrderedDict(sorted(genres.items(), key=lambda t: t[1])).keys()

plt.figure(figsize=(8,8))
plot_confusion_matrix(cm, keys, normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# # Test data process

# %%
#load model
model = load_model('./VGG16.h5')

# %%
# Parameters
test_dir = './GTZAN/genres/testing_set'
song_samples = 660000

# %%
def create_filename_list(src_dir):
    filename_list = []
    for root, subdirs, files in os.walk(src_dir):
        for file in files:
            filename_list.append(file)
    return filename_list

# %%
def read_test_data(src_dir, song_samples, spec_format):
    arr_specs = []
    music_splits_len = []
    
    for root, subdirs, files in os.walk(src_dir):
        for file in files:
            file_name = src_dir + "/" + file
            signal, sr = librosa.load(file_name)
            
            # target_samples = signal.shape[0] - (signal.shape[0] % sr)
            signal = signal[:song_samples]
                        
            # Convert to dataset of spectograms/melspectograms
            signals = splitsongs_for_test(signal, music_splits_len)
                
            # Convert to "spec" representation
            specs = spec_format(signals)
                
            # Save files
            arr_specs.extend(specs)
    return np.array(arr_specs), music_splits_len

# %%
"""
@description: Method to split a song into multiple songs using overlapping windows
"""
def splitsongs_for_test(X, music_splits_len, window = 0.1, overlap = 0.5):
    # Empty lists to hold our results
    temp_X = []

    # Get the input song array size
    xshape = X.shape[0]
    chunk = int(xshape*window)
    offset = int(chunk*(1.-overlap))
    
    # Split the song and create new ones on windows
    spsong = [X[i:i+chunk] for i in range(0, xshape - chunk + offset, offset)]
    for s in spsong:
        temp_X.append(s)
    music_splits_len.append(len(temp_X))
    return np.array(temp_X)

# %%
test_x, music_splits_len = read_test_data(test_dir, song_samples, to_melspectrogram)

# %%
# Read the data
np.save('test_x_v3_npy.npy', test_x)

# %%
X_test = np.load('test_x_v3_npy.npy')

# %%
X_test_stack = np.squeeze(np.stack((X_test,) * 3, -1))

# %%
predict_result = model.predict(X_test_stack)

# %%
def group_predict_result(predict_result, music_splits_len):
    grouping_predict_result = []
    delete_result = predict_result
    for length in music_splits_len:
        temp_grouping = []
        for i in range(length):
            temp_grouping.append(delete_result[0])
            delete_result = np.delete(delete_result, [0], axis=0)
        grouping_predict_result.append(temp_grouping)
    return grouping_predict_result

# %%
def most_frequent(List): 
    counter = 0
    num = List[0]
    for i in List: 
        curr_frequency = List.count(i) 
        if(curr_frequency> counter): 
            counter = curr_frequency 
            num = i
    return num

# %%
def get_predict_result(grouping_predict):
    final_result = []
    for group in grouping_predict:
        group_indexs = []
        for item in group:
            max = np.argmax(item, axis=0)
            group_indexs.append(max.tolist())
        max_duplicated_value = most_frequent(group_indexs)
        final_result.append(max_duplicated_value)
    return final_result

# %%
grouping_predict = group_predict_result(predict_result, music_splits_len)

# %%
final_predict = get_predict_result(grouping_predict)

# %%
filename_list = create_filename_list(test_dir)

# %%
predict = pd.DataFrame({"id":filename_list, "class":final_predict})

# %%
predict.to_csv("v3_submission.csv", index = False)

# %%
predict
# Out:
#                     id  class
# 0      hiphop.00092.au      2
# 1        rock.00095.au      5
# 2       disco.00094.au      4
# 3       blues.00095.au      0
# 4   classical.00091.au      1
# 5      hiphop.00099.au      2
# 6      hiphop.00094.au      2
# 7       disco.00092.au      4
# 8       disco.00098.au      4
# 9        rock.00093.au      5
# 10       jazz.00092.au      3
# 11      blues.00091.au      0
# 12       jazz.00097.au      1
# 13       rock.00092.au      5
# 14     hiphop.00091.au      2
# 15      blues.00098.au      5
# 16  classical.00097.au      1
# 17       rock.00099.au      5
# 18      disco.00090.au      4
# 19       rock.00096.au      5
# 20       jazz.00099.au      3
# 21  classical.00090.au      1
# 22     hiphop.00093.au      2
# 23     hiphop.00090.au      2
# 24      disco.00097.au      4
# 25      disco.00099.au      4
# 26  classical.00095.au      1
# 27      blues.00090.au      0
# 28       rock.00097.au      5
# 29     hiphop.00098.au      2
# 30       jazz.00093.au      3
# 31       rock.00094.au      5
# 32  classical.00092.au      1
# 33      blues.00093.au      3
# 34       jazz.00091.au      1
# 35       jazz.00090.au      3
# 36       jazz.00098.au      3
# 37  classical.00093.au      1
# 38      disco.00093.au      4
# 39       jazz.00094.au      3
# 40      blues.00092.au      3
# 41  classical.00099.au      1
# 42  classical.00096.au      1
# 43     hiphop.00097.au      2
# 44       jazz.00096.au      3
# 45       rock.00098.au      5
# 46       jazz.00095.au      3
# 47      blues.00096.au      3
# 48       rock.00091.au      5
# 49      blues.00099.au      0
# 50      disco.00091.au      4
# 51      blues.00094.au      0
# 52  classical.00098.au      1
# 53     hiphop.00095.au      5
# 54      disco.00095.au      4
# 55       rock.00090.au      0
# 56  classical.00094.au      1
# 57      blues.00097.au      0
# 58     hiphop.00096.au      2
# 59      disco.00096.au      5

# %%
genres = {'blues': 0, 'classical': 1, 'hiphop': 2, 'jazz': 3, 'disco':4, 'rock':5}

# %%
# genres = {'blues': 0, 'classical': 1, 'country': 2, 'disco': 3, 'hiphop': 4,
#           'jazz': 5, 'metal': 6, 'pop': 7, 'reggae': 8, 'rock': 9}

# %%
def getLables():
    labels = []
    for filename in filename_list:
        str_list = filename.split('.')
        labels.append(str_list[0])
    return labels

# %%
labels = getLables()

# %%
solution = pd.DataFrame({"id":filename_list, "class_truth":labels})

# %%
mapping = genres

# %%
solution['class_truth'] = solution['class_truth'].map(mapping)

# %%
total_count = len(solution['class_truth'])

# %%
def caculate_accuracy(total_count):
    correct = 0
    for i in range(total_count):
        print('==============================================================')
        print('solution index ' + str(i) + ' = ' + str(solution['class_truth'][i]))
        print('predict index ' + str(i) + ' = ' + str(predict['class'][i]))
        if(solution['class_truth'][i] == predict['class'][i]):
            print('predict correct')
            correct += 1
    return correct / total_count

# %%
caculate_accuracy(total_count)
# Out:
# ==============================================================
# solution index 0 = 2
# predict index 0 = 2
# predict correct
# ==============================================================
# solution index 1 = 5
# predict index 1 = 5
# predict correct
# ==============================================================
# solution index 2 = 4
# predict index 2 = 4
# predict correct
# ==============================================================
# solution index 3 = 0
# predict index 3 = 0
# predict correct
# ==============================================================
# solution index 4 = 1
# predict index 4 = 1
# predict correct
# ==============================================================
# solution index 5 = 2
# predict index 5 = 2
# predict correct
# ==============================================================
# solution index 6 = 2
# predict index 6 = 2
# predict correct
# ==============================================================
# solution index 7 = 4
# predict index 7 = 4
# predict correct
# ==============================================================
# solution index 8 = 4
# predict index 8 = 4
# predict correct
# ==============================================================
# solution index 9 = 5
# predict index 9 = 5
# predict correct
# ==============================================================
# solution index 10 = 3
# predict index 10 = 3
# predict correct
# ==============================================================
# solution index 11 = 0
# predict index 11 = 0
# predict correct
# ==============================================================
# solution index 12 = 3
# predict index 12 = 1
# ==============================================================
# solution index 13 = 5
# predict index 13 = 5
# predict correct
# ==============================================================
# solution index 14 = 2
# predict index 14 = 2
# predict correct
# ==============================================================
# solution index 15 = 0
# predict index 15 = 5
# ==============================================================
# solution index 16 = 1
# predict index 16 = 1
# predict correct
# ==============================================================
# solution index 17 = 5
# predict index 17 = 5
# predict correct
# ==============================================================
# solution index 18 = 4
# predict index 18 = 4
# predict correct
# ==============================================================
# solution index 19 = 5
# predict index 19 = 5
# predict correct
# ==============================================================
# solution index 20 = 3
# predict index 20 = 3
# predict correct
# ==============================================================
# solution index 21 = 1
# predict index 21 = 1
# predict correct
# ==============================================================
# solution index 22 = 2
# predict index 22 = 2
# predict correct
# ==============================================================
# solution index 23 = 2
# predict index 23 = 2
# predict correct
# ==============================================================
# solution index 24 = 4
# predict index 24 = 4
# predict correct
# ==============================================================
# solution index 25 = 4
# predict index 25 = 4
# predict correct
# ==============================================================
# solution index 26 = 1
# predict index 26 = 1
# predict correct
# ==============================================================
# solution index 27 = 0
# predict index 27 = 0
# predict correct
# ==============================================================
# solution index 28 = 5
# predict index 28 = 5
# predict correct
# ==============================================================
# solution index 29 = 2
# predict index 29 = 2
# predict correct
# ==============================================================
# solution index 30 = 3
# predict index 30 = 3
# predict correct
# ==============================================================
# solution index 31 = 5
# predict index 31 = 5
# predict correct
# ==============================================================
# solution index 32 = 1
# predict index 32 = 1
# predict correct
# ==============================================================
# solution index 33 = 0
# predict index 33 = 3
# ==============================================================
# solution index 34 = 3
# predict index 34 = 1
# ==============================================================
# solution index 35 = 3
# predict index 35 = 3
# predict correct
# ==============================================================
# solution index 36 = 3
# predict index 36 = 3
# predict correct
# ==============================================================
# solution index 37 = 1
# predict index 37 = 1
# predict correct
# ==============================================================
# solution index 38 = 4
# predict index 38 = 4
# predict correct
# ==============================================================
# solution index 39 = 3
# predict index 39 = 3
# predict correct
# ==============================================================
# solution index 40 = 0
# predict index 40 = 3
# ==============================================================
# solution index 41 = 1
# predict index 41 = 1
# predict correct
# ==============================================================
# solution index 42 = 1
# predict index 42 = 1
# predict correct
# ==============================================================
# solution index 43 = 2
# predict index 43 = 2
# predict correct
# ==============================================================
# solution index 44 = 3
# predict index 44 = 3
# predict correct
# ==============================================================
# solution index 45 = 5
# predict index 45 = 5
# predict correct
# ==============================================================
# solution index 46 = 3
# predict index 46 = 3
# predict correct
# ==============================================================
# solution index 47 = 0
# predict index 47 = 3
# ==============================================================
# solution index 48 = 5
# predict index 48 = 5
# predict correct
# ==============================================================
# solution index 49 = 0
# predict index 49 = 0
# predict correct
# ==============================================================
# solution index 50 = 4
# predict index 50 = 4
# predict correct
# ==============================================================
# solution index 51 = 0
# predict index 51 = 0
# predict correct
# ==============================================================
# solution index 52 = 1
# predict index 52 = 1
# predict correct
# ==============================================================
# solution index 53 = 2
# predict index 53 = 5
# ==============================================================
# solution index 54 = 4
# predict index 54 = 4
# predict correct
# ==============================================================
# solution index 55 = 5
# predict index 55 = 0
# ==============================================================
# solution index 56 = 1
# predict index 56 = 1
# predict correct
# ==============================================================
# solution index 57 = 0
# predict index 57 = 0
# predict correct
# ==============================================================
# solution index 58 = 2
# predict index 58 = 2
# predict correct
# ==============================================================
# solution index 59 = 4
# predict index 59 = 5
# 0.85

# %%
compare = pd.concat([solution, predict.iloc[:, 1]], axis=1)

# %%
compare
# Out:
#                     id  class_truth  class
# 0      hiphop.00092.au            2      2
# 1        rock.00095.au            5      5
# 2       disco.00094.au            4      4
# 3       blues.00095.au            0      0
# 4   classical.00091.au            1      1
# 5      hiphop.00099.au            2      2
# 6      hiphop.00094.au            2      2
# 7       disco.00092.au            4      4
# 8       disco.00098.au            4      4
# 9        rock.00093.au            5      5
# 10       jazz.00092.au            3      3
# 11      blues.00091.au            0      0
# 12       jazz.00097.au            3      1
# 13       rock.00092.au            5      5
# 14     hiphop.00091.au            2      2
# 15      blues.00098.au            0      5
# 16  classical.00097.au            1      1
# 17       rock.00099.au            5      5
# 18      disco.00090.au            4      4
# 19       rock.00096.au            5      5
# 20       jazz.00099.au            3      3
# 21  classical.00090.au            1      1
# 22     hiphop.00093.au            2      2
# 23     hiphop.00090.au            2      2
# 24      disco.00097.au            4      4
# 25      disco.00099.au            4      4
# 26  classical.00095.au            1      1
# 27      blues.00090.au            0      0
# 28       rock.00097.au            5      5
# 29     hiphop.00098.au            2      2
# 30       jazz.00093.au            3      3
# 31       rock.00094.au            5      5
# 32  classical.00092.au            1      1
# 33      blues.00093.au            0      3
# 34       jazz.00091.au            3      1
# 35       jazz.00090.au            3      3
# 36       jazz.00098.au            3      3
# 37  classical.00093.au            1      1
# 38      disco.00093.au            4      4
# 39       jazz.00094.au            3      3
# 40      blues.00092.au            0      3
# 41  classical.00099.au            1      1
# 42  classical.00096.au            1      1
# 43     hiphop.00097.au            2      2
# 44       jazz.00096.au            3      3
# 45       rock.00098.au            5      5
# 46       jazz.00095.au            3      3
# 47      blues.00096.au            0      3
# 48       rock.00091.au            5      5
# 49      blues.00099.au            0      0
# 50      disco.00091.au            4      4
# 51      blues.00094.au            0      0
# 52  classical.00098.au            1      1
# 53     hiphop.00095.au            2      5
# 54      disco.00095.au            4      4
# 55       rock.00090.au            5      0
# 56  classical.00094.au            1      1
# 57      blues.00097.au            0      0
# 58     hiphop.00096.au            2      2
# 59      disco.00096.au            4      5

# %%
comp = pd.DataFrame(compare)
comp.to_csv('./comp.csv', index=False)

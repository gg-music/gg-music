# %%
# !pip install librosa
# Out:
# Collecting librosa
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (1.15.2)
# Requirement already satisfied: six>=1.3 in /opt/conda/lib/python3.6/site-packages (from librosa) (1.11.0)
# Collecting soundfile>=0.9.0 (from librosa)
#   Using cached https://files.pythonhosted.org/packages/68/64/1191352221e2ec90db7492b4bf0c04fd9d2508de67b3f39cbf093cd6bd86/SoundFile-0.10.2-py2.py3-none-any.whl
# Collecting joblib>=0.12 (from librosa)
#   Using cached https://files.pythonhosted.org/packages/8f/42/155696f85f344c066e17af287359c9786b436b1bf86029bb3411283274f3/joblib-0.14.0-py2.py3-none-any.whl
# Collecting resampy>=0.2.0 (from librosa)
# Collecting audioread>=2.0.0 (from librosa)
# Requirement already satisfied: decorator>=3.0.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (4.3.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: numba>=0.38.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.38.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from librosa) (0.19.2)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.6/site-packages (from soundfile>=0.9.0->librosa) (1.11.5)
# Requirement already satisfied: llvmlite>=0.23.0dev0 in /opt/conda/lib/python3.6/site-packages (from numba>=0.38.0->librosa) (0.23.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.18)
# Installing collected packages: soundfile, joblib, resampy, audioread, librosa
# Successfully installed audioread-2.1.8 joblib-0.14.0 librosa-0.7.0 resampy-0.2.2 soundfile-0.10.2

# %%
import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

import os
import keras
import h5py
import librosa
import itertools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
from collections import OrderedDict

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Input
from keras.layers import Dropout
from keras.models import Model
from keras.applications.vgg16 import VGG16
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Read the data
#
# > Helper functions to assist the process to read songs, split then and return an array of spectrograms/melspectrograms

# %%
"""
@description: Method to split a song into multiple songs using overlapping windows
"""
def splitsongs(X, y, window = 0.1, overlap = 0.5):
    # Empty lists to hold our results
    temp_X = []
    temp_y = []

    # Get the input song array size
    xshape = X.shape[0]
    chunk = int(xshape*window)
    offset = int(chunk*(1.-overlap))
    
    # Split the song and create new ones on windows
    spsong = [X[i:i+chunk] for i in range(0, xshape - chunk + offset, offset)]
    for s in spsong:
        temp_X.append(s)
        temp_y.append(y)

    return np.array(temp_X), np.array(temp_y)

# %%
"""
@description: Method to convert a list of songs to a np array of melspectrograms
"""
def to_melspectrogram(songs, n_fft = 1024, hop_length = 512):
    # Transformation function
    melspec = lambda x: librosa.feature.melspectrogram(x, n_fft = n_fft,
        hop_length = hop_length)[:,:,np.newaxis]

    # map transformation of input songs to melspectrogram using log-scale
    tsongs = map(melspec, songs)
    return np.array(list(tsongs))

# %%
def read_data(src_dir, genres, song_samples, spec_format, debug = True):    
    # Empty array of dicts with the processed features from all files
    arr_specs = []
    arr_genres = []

    # Read files from the folders
    for x,_ in genres.items():
        folder = src_dir + x
        print(folder)
        for root, subdirs, files in os.walk(folder):
            for file in files:
                # Read the audio file
                file_name = folder + "/" + file
                print(file_name)
                signal, sr = librosa.load(file_name)
                signal = signal[:song_samples]
                
                # Debug process
                if debug:
                    print("Reading file: {}".format(file_name))
                
                # Convert to dataset of spectograms/melspectograms
                signals, y = splitsongs(signal, genres[x])
                
                # Convert to "spec" representation
                specs = spec_format(signals)
                
                # Save files
                arr_genres.extend(y)
                arr_specs.extend(specs)
                
                
    return np.array(arr_specs), np.array(arr_genres)

# %%
# Parameters
gtzan_dir = '../Final_report/gtzan_training/genres/'
song_samples = 660000
genres = {'classical': 2, 'hiphop': 3, 'jazz': 4, 'blues': 7, 'rock': 9}

# %%
# Read the data
X, y = read_data(gtzan_dir, genres, song_samples, to_melspectrogram, debug=False)
np.save('x_gtzan_npy_v6.npy', X)
np.save('y_gtzan_npy_v6.npy', y)
# Out:
# ../Final_report/gtzan_training/genres/classical
# ../Final_report/gtzan_training/genres/classical/classical.00013.wav
# ../Final_report/gtzan_training/genres/classical/classical.00077.wav
# ../Final_report/gtzan_training/genres/classical/classical.00045.wav
# ../Final_report/gtzan_training/genres/classical/classical.00076.wav
# ../Final_report/gtzan_training/genres/classical/classical.00041.wav
# ../Final_report/gtzan_training/genres/classical/classical.00015.wav
# ../Final_report/gtzan_training/genres/classical/classical.00039.wav
# ../Final_report/gtzan_training/genres/classical/classical.00024.wav
# ../Final_report/gtzan_training/genres/classical/classical.00007.wav
# ../Final_report/gtzan_training/genres/classical/classical.00067.wav
# ../Final_report/gtzan_training/genres/classical/classical.00062.wav
# ../Final_report/gtzan_training/genres/classical/classical.00052.wav
# ../Final_report/gtzan_training/genres/classical/classical.00038.wav
# ../Final_report/gtzan_training/genres/classical/classical.00055.wav
# ../Final_report/gtzan_training/genres/classical/classical.00003.wav
# ../Final_report/gtzan_training/genres/classical/classical.00029.wav
# ../Final_report/gtzan_training/genres/classical/classical.00011.wav
# ../Final_report/gtzan_training/genres/classical/classical.00004.wav
# ../Final_report/gtzan_training/genres/classical/classical.00069.wav
# ../Final_report/gtzan_training/genres/classical/classical.00021.wav
# ../Final_report/gtzan_training/genres/classical/classical.00078.wav
# ../Final_report/gtzan_training/genres/classical/classical.00017.wav
# ../Final_report/gtzan_training/genres/classical/classical.00053.wav
# ../Final_report/gtzan_training/genres/classical/classical.00020.wav
# ../Final_report/gtzan_training/genres/classical/classical.00071.wav
# ../Final_report/gtzan_training/genres/classical/classical.00005.wav
# ../Final_report/gtzan_training/genres/classical/classical.00035.wav
# ../Final_report/gtzan_training/genres/classical/classical.00006.wav
# ../Final_report/gtzan_training/genres/classical/classical.00046.wav
# ../Final_report/gtzan_training/genres/classical/classical.00047.wav
# ../Final_report/gtzan_training/genres/classical/classical.00037.wav
# ../Final_report/gtzan_training/genres/classical/classical.00016.wav
# ../Final_report/gtzan_training/genres/classical/classical.00064.wav
# ../Final_report/gtzan_training/genres/classical/classical.00043.wav
# ../Final_report/gtzan_training/genres/classical/classical.00008.wav
# ../Final_report/gtzan_training/genres/classical/classical.00044.wav
# ../Final_report/gtzan_training/genres/classical/classical.00034.wav
# ../Final_report/gtzan_training/genres/classical/classical.00048.wav
# ../Final_report/gtzan_training/genres/classical/classical.00033.wav
# ../Final_report/gtzan_training/genres/classical/classical.00025.wav
# ../Final_report/gtzan_training/genres/classical/classical.00083.wav
# ../Final_report/gtzan_training/genres/classical/classical.00019.wav
# ../Final_report/gtzan_training/genres/classical/classical.00023.wav
# ../Final_report/gtzan_training/genres/classical/classical.00040.wav
# ../Final_report/gtzan_training/genres/classical/classical.00054.wav
# ../Final_report/gtzan_training/genres/classical/classical.00072.wav
# ../Final_report/gtzan_training/genres/classical/classical.00066.wav
# ../Final_report/gtzan_training/genres/classical/classical.00030.wav
# ../Final_report/gtzan_training/genres/classical/classical.00059.wav
# ../Final_report/gtzan_training/genres/classical/classical.00058.wav
# ../Final_report/gtzan_training/genres/classical/classical.00089.wav
# ../Final_report/gtzan_training/genres/classical/classical.00010.wav
# ../Final_report/gtzan_training/genres/classical/classical.00087.wav
# ../Final_report/gtzan_training/genres/classical/classical.00060.wav
# ../Final_report/gtzan_training/genres/classical/classical.00070.wav
# ../Final_report/gtzan_training/genres/classical/classical.00068.wav
# ../Final_report/gtzan_training/genres/classical/classical.00018.wav
# ../Final_report/gtzan_training/genres/classical/classical.00027.wav
# ../Final_report/gtzan_training/genres/classical/classical.00036.wav
# ../Final_report/gtzan_training/genres/classical/classical.00088.wav
# ../Final_report/gtzan_training/genres/classical/classical.00063.wav
# ../Final_report/gtzan_training/genres/classical/classical.00061.wav
# ../Final_report/gtzan_training/genres/classical/classical.00081.wav
# ../Final_report/gtzan_training/genres/classical/classical.00079.wav
# ../Final_report/gtzan_training/genres/classical/classical.00050.wav
# ../Final_report/gtzan_training/genres/classical/classical.00000.wav
# ../Final_report/gtzan_training/genres/classical/classical.00012.wav
# ../Final_report/gtzan_training/genres/classical/classical.00022.wav
# ../Final_report/gtzan_training/genres/classical/classical.00049.wav
# ../Final_report/gtzan_training/genres/classical/classical.00065.wav
# ../Final_report/gtzan_training/genres/classical/classical.00031.wav
# ../Final_report/gtzan_training/genres/classical/classical.00014.wav
# ../Final_report/gtzan_training/genres/classical/classical.00075.wav
# ../Final_report/gtzan_training/genres/classical/classical.00073.wav
# ../Final_report/gtzan_training/genres/classical/classical.00082.wav
# ../Final_report/gtzan_training/genres/classical/classical.00042.wav
# ../Final_report/gtzan_training/genres/classical/classical.00002.wav
# ../Final_report/gtzan_training/genres/classical/classical.00080.wav
# ../Final_report/gtzan_training/genres/classical/classical.00051.wav
# ../Final_report/gtzan_training/genres/classical/classical.00085.wav
# ../Final_report/gtzan_training/genres/classical/classical.00009.wav
# ../Final_report/gtzan_training/genres/classical/classical.00086.wav
# ../Final_report/gtzan_training/genres/classical/classical.00057.wav
# ../Final_report/gtzan_training/genres/classical/classical.00032.wav
# ../Final_report/gtzan_training/genres/classical/classical.00001.wav
# ../Final_report/gtzan_training/genres/classical/classical.00056.wav
# ../Final_report/gtzan_training/genres/classical/classical.00074.wav
# ../Final_report/gtzan_training/genres/classical/classical.00084.wav
# ../Final_report/gtzan_training/genres/classical/classical.00026.wav
# ../Final_report/gtzan_training/genres/classical/classical.00028.wav
# ../Final_report/gtzan_training/genres/hiphop
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00089.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00063.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00033.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00031.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00028.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00021.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00067.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00050.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00024.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00065.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00051.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00057.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00017.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00036.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00076.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00008.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00012.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00068.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00022.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00071.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00073.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00041.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00004.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00027.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00085.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00079.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00058.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00007.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00026.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00083.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00045.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00042.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00070.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00014.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00053.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00003.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00037.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00081.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00002.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00040.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00080.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00066.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00075.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00025.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00009.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00055.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00087.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00013.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00054.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00030.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00019.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00006.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00015.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00062.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00047.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00059.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00044.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00074.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00011.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00072.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00078.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00046.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00060.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00034.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00088.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00082.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00049.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00001.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00010.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00056.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00061.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00005.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00084.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00064.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00018.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00029.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00043.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00052.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00048.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00020.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00032.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00086.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00035.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00000.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00069.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00023.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00039.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00038.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00016.wav
# ../Final_report/gtzan_training/genres/hiphop/hiphop.00077.wav
# ../Final_report/gtzan_training/genres/jazz
# ../Final_report/gtzan_training/genres/jazz/jazz.00082.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00019.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00003.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00007.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00061.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00054.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00033.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00013.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00021.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00055.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00002.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00040.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00022.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00044.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00069.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00071.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00027.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00038.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00036.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00048.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00059.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00020.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00073.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00023.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00050.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00042.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00008.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00031.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00047.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00015.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00089.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00070.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00063.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00086.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00060.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00028.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00081.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00005.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00072.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00032.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00009.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00077.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00053.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00024.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00066.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00043.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00017.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00076.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00080.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00046.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00056.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00088.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00084.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00011.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00000.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00025.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00018.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00085.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00067.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00079.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00045.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00012.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00004.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00026.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00016.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00035.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00064.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00058.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00030.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00014.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00068.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00057.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00051.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00034.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00065.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00083.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00029.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00037.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00039.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00006.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00049.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00078.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00052.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00087.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00062.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00074.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00041.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00001.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00075.wav
# ../Final_report/gtzan_training/genres/jazz/jazz.00010.wav
# ../Final_report/gtzan_training/genres/blues
# ../Final_report/gtzan_training/genres/blues/blues.00019.wav
# ../Final_report/gtzan_training/genres/blues/blues.00057.wav
# ../Final_report/gtzan_training/genres/blues/blues.00002.wav
# ../Final_report/gtzan_training/genres/blues/blues.00050.wav
# ../Final_report/gtzan_training/genres/blues/blues.00062.wav
# ../Final_report/gtzan_training/genres/blues/blues.00048.wav
# ../Final_report/gtzan_training/genres/blues/blues.00047.wav
# ../Final_report/gtzan_training/genres/blues/blues.00040.wav
# ../Final_report/gtzan_training/genres/blues/blues.00063.wav
# ../Final_report/gtzan_training/genres/blues/blues.00088.wav
# ../Final_report/gtzan_training/genres/blues/blues.00078.wav
# ../Final_report/gtzan_training/genres/blues/blues.00028.wav
# ../Final_report/gtzan_training/genres/blues/blues.00065.wav
# ../Final_report/gtzan_training/genres/blues/blues.00058.wav
# ../Final_report/gtzan_training/genres/blues/blues.00085.wav
# ../Final_report/gtzan_training/genres/blues/blues.00069.wav
# ../Final_report/gtzan_training/genres/blues/blues.00022.wav
# ../Final_report/gtzan_training/genres/blues/blues.00012.wav
# ../Final_report/gtzan_training/genres/blues/blues.00025.wav
# ../Final_report/gtzan_training/genres/blues/blues.00016.wav
# ../Final_report/gtzan_training/genres/blues/blues.00032.wav
# ../Final_report/gtzan_training/genres/blues/blues.00042.wav
# ../Final_report/gtzan_training/genres/blues/blues.00075.wav
# ../Final_report/gtzan_training/genres/blues/blues.00009.wav
# ../Final_report/gtzan_training/genres/blues/blues.00041.wav
# ../Final_report/gtzan_training/genres/blues/blues.00035.wav
# ../Final_report/gtzan_training/genres/blues/blues.00024.wav
# ../Final_report/gtzan_training/genres/blues/blues.00076.wav
# ../Final_report/gtzan_training/genres/blues/blues.00027.wav
# ../Final_report/gtzan_training/genres/blues/blues.00000.wav
# ../Final_report/gtzan_training/genres/blues/blues.00029.wav
# ../Final_report/gtzan_training/genres/blues/blues.00082.wav
# ../Final_report/gtzan_training/genres/blues/blues.00001.wav
# ../Final_report/gtzan_training/genres/blues/blues.00013.wav
# ../Final_report/gtzan_training/genres/blues/blues.00055.wav
# ../Final_report/gtzan_training/genres/blues/blues.00017.wav
# ../Final_report/gtzan_training/genres/blues/blues.00037.wav
# ../Final_report/gtzan_training/genres/blues/blues.00079.wav
# ../Final_report/gtzan_training/genres/blues/blues.00067.wav
# ../Final_report/gtzan_training/genres/blues/blues.00071.wav
# ../Final_report/gtzan_training/genres/blues/blues.00081.wav
# ../Final_report/gtzan_training/genres/blues/blues.00030.wav
# ../Final_report/gtzan_training/genres/blues/blues.00003.wav
# ../Final_report/gtzan_training/genres/blues/blues.00034.wav
# ../Final_report/gtzan_training/genres/blues/blues.00066.wav
# ../Final_report/gtzan_training/genres/blues/blues.00010.wav
# ../Final_report/gtzan_training/genres/blues/blues.00089.wav
# ../Final_report/gtzan_training/genres/blues/blues.00086.wav
# ../Final_report/gtzan_training/genres/blues/blues.00031.wav
# ../Final_report/gtzan_training/genres/blues/blues.00033.wav
# ../Final_report/gtzan_training/genres/blues/blues.00077.wav
# ../Final_report/gtzan_training/genres/blues/blues.00006.wav
# ../Final_report/gtzan_training/genres/blues/blues.00038.wav
# ../Final_report/gtzan_training/genres/blues/blues.00043.wav
# ../Final_report/gtzan_training/genres/blues/blues.00045.wav
# ../Final_report/gtzan_training/genres/blues/blues.00059.wav
# ../Final_report/gtzan_training/genres/blues/blues.00068.wav
# ../Final_report/gtzan_training/genres/blues/blues.00073.wav
# ../Final_report/gtzan_training/genres/blues/blues.00052.wav
# ../Final_report/gtzan_training/genres/blues/blues.00014.wav
# ../Final_report/gtzan_training/genres/blues/blues.00072.wav
# ../Final_report/gtzan_training/genres/blues/blues.00064.wav
# ../Final_report/gtzan_training/genres/blues/blues.00020.wav
# ../Final_report/gtzan_training/genres/blues/blues.00074.wav
# ../Final_report/gtzan_training/genres/blues/blues.00080.wav
# ../Final_report/gtzan_training/genres/blues/blues.00061.wav
# ../Final_report/gtzan_training/genres/blues/blues.00083.wav
# ../Final_report/gtzan_training/genres/blues/blues.00049.wav
# ../Final_report/gtzan_training/genres/blues/blues.00018.wav
# ../Final_report/gtzan_training/genres/blues/blues.00070.wav
# ../Final_report/gtzan_training/genres/blues/blues.00011.wav
# ../Final_report/gtzan_training/genres/blues/blues.00021.wav
# ../Final_report/gtzan_training/genres/blues/blues.00023.wav
# ../Final_report/gtzan_training/genres/blues/blues.00005.wav
# ../Final_report/gtzan_training/genres/blues/blues.00015.wav
# ../Final_report/gtzan_training/genres/blues/blues.00036.wav
# ../Final_report/gtzan_training/genres/blues/blues.00044.wav
# ../Final_report/gtzan_training/genres/blues/blues.00056.wav
# ../Final_report/gtzan_training/genres/blues/blues.00053.wav
# ../Final_report/gtzan_training/genres/blues/blues.00087.wav
# ../Final_report/gtzan_training/genres/blues/blues.00026.wav
# ../Final_report/gtzan_training/genres/blues/blues.00039.wav
# ../Final_report/gtzan_training/genres/blues/blues.00007.wav
# ../Final_report/gtzan_training/genres/blues/blues.00051.wav
# ../Final_report/gtzan_training/genres/blues/blues.00084.wav
# ../Final_report/gtzan_training/genres/blues/blues.00046.wav
# ../Final_report/gtzan_training/genres/blues/blues.00004.wav
# ../Final_report/gtzan_training/genres/blues/blues.00008.wav
# ../Final_report/gtzan_training/genres/blues/blues.00060.wav
# ../Final_report/gtzan_training/genres/blues/blues.00054.wav
# ../Final_report/gtzan_training/genres/rock
# ../Final_report/gtzan_training/genres/rock/rock.00016.wav
# ../Final_report/gtzan_training/genres/rock/rock.00086.wav
# ../Final_report/gtzan_training/genres/rock/rock.00024.wav
# ../Final_report/gtzan_training/genres/rock/rock.00020.wav
# ../Final_report/gtzan_training/genres/rock/rock.00087.wav
# ../Final_report/gtzan_training/genres/rock/rock.00036.wav
# ../Final_report/gtzan_training/genres/rock/rock.00044.wav
# ../Final_report/gtzan_training/genres/rock/rock.00030.wav
# ../Final_report/gtzan_training/genres/rock/rock.00009.wav
# ../Final_report/gtzan_training/genres/rock/rock.00083.wav
# ../Final_report/gtzan_training/genres/rock/rock.00001.wav
# ../Final_report/gtzan_training/genres/rock/rock.00029.wav
# ../Final_report/gtzan_training/genres/rock/rock.00002.wav
# ../Final_report/gtzan_training/genres/rock/rock.00019.wav
# ../Final_report/gtzan_training/genres/rock/rock.00068.wav
# ../Final_report/gtzan_training/genres/rock/rock.00035.wav
# ../Final_report/gtzan_training/genres/rock/rock.00078.wav
# ../Final_report/gtzan_training/genres/rock/rock.00085.wav
# ../Final_report/gtzan_training/genres/rock/rock.00082.wav
# ../Final_report/gtzan_training/genres/rock/rock.00021.wav
# ../Final_report/gtzan_training/genres/rock/rock.00033.wav
# ../Final_report/gtzan_training/genres/rock/rock.00067.wav
# ../Final_report/gtzan_training/genres/rock/rock.00012.wav
# ../Final_report/gtzan_training/genres/rock/rock.00058.wav
# ../Final_report/gtzan_training/genres/rock/rock.00023.wav
# ../Final_report/gtzan_training/genres/rock/rock.00054.wav
# ../Final_report/gtzan_training/genres/rock/rock.00065.wav
# ../Final_report/gtzan_training/genres/rock/rock.00084.wav
# ../Final_report/gtzan_training/genres/rock/rock.00005.wav
# ../Final_report/gtzan_training/genres/rock/rock.00034.wav
# ../Final_report/gtzan_training/genres/rock/rock.00088.wav
# ../Final_report/gtzan_training/genres/rock/rock.00006.wav
# ../Final_report/gtzan_training/genres/rock/rock.00081.wav
# ../Final_report/gtzan_training/genres/rock/rock.00013.wav
# ../Final_report/gtzan_training/genres/rock/rock.00047.wav
# ../Final_report/gtzan_training/genres/rock/rock.00015.wav
# ../Final_report/gtzan_training/genres/rock/rock.00074.wav
# ../Final_report/gtzan_training/genres/rock/rock.00073.wav
# ../Final_report/gtzan_training/genres/rock/rock.00071.wav
# ../Final_report/gtzan_training/genres/rock/rock.00066.wav
# ../Final_report/gtzan_training/genres/rock/rock.00041.wav
# ../Final_report/gtzan_training/genres/rock/rock.00062.wav
# ../Final_report/gtzan_training/genres/rock/rock.00000.wav
# ../Final_report/gtzan_training/genres/rock/rock.00052.wav
# ../Final_report/gtzan_training/genres/rock/rock.00037.wav
# ../Final_report/gtzan_training/genres/rock/rock.00048.wav
# ../Final_report/gtzan_training/genres/rock/rock.00072.wav
# ../Final_report/gtzan_training/genres/rock/rock.00026.wav
# ../Final_report/gtzan_training/genres/rock/rock.00003.wav
# ../Final_report/gtzan_training/genres/rock/rock.00057.wav
# ../Final_report/gtzan_training/genres/rock/rock.00055.wav
# ../Final_report/gtzan_training/genres/rock/rock.00049.wav
# ../Final_report/gtzan_training/genres/rock/rock.00018.wav
# ../Final_report/gtzan_training/genres/rock/rock.00053.wav
# ../Final_report/gtzan_training/genres/rock/rock.00028.wav
# ../Final_report/gtzan_training/genres/rock/rock.00061.wav
# ../Final_report/gtzan_training/genres/rock/rock.00050.wav
# ../Final_report/gtzan_training/genres/rock/rock.00038.wav
# ../Final_report/gtzan_training/genres/rock/rock.00010.wav
# ../Final_report/gtzan_training/genres/rock/rock.00089.wav
# ../Final_report/gtzan_training/genres/rock/rock.00031.wav
# ../Final_report/gtzan_training/genres/rock/rock.00027.wav
# ../Final_report/gtzan_training/genres/rock/rock.00069.wav
# ../Final_report/gtzan_training/genres/rock/rock.00014.wav
# ../Final_report/gtzan_training/genres/rock/rock.00077.wav
# ../Final_report/gtzan_training/genres/rock/rock.00070.wav
# ../Final_report/gtzan_training/genres/rock/rock.00063.wav
# ../Final_report/gtzan_training/genres/rock/rock.00051.wav
# ../Final_report/gtzan_training/genres/rock/rock.00022.wav
# ../Final_report/gtzan_training/genres/rock/rock.00045.wav
# ../Final_report/gtzan_training/genres/rock/rock.00056.wav
# ../Final_report/gtzan_training/genres/rock/rock.00040.wav
# ../Final_report/gtzan_training/genres/rock/rock.00032.wav
# ../Final_report/gtzan_training/genres/rock/rock.00008.wav
# ../Final_report/gtzan_training/genres/rock/rock.00011.wav
# ../Final_report/gtzan_training/genres/rock/rock.00075.wav
# ../Final_report/gtzan_training/genres/rock/rock.00039.wav
# ../Final_report/gtzan_training/genres/rock/rock.00043.wav
# ../Final_report/gtzan_training/genres/rock/rock.00079.wav
# ../Final_report/gtzan_training/genres/rock/rock.00007.wav
# ../Final_report/gtzan_training/genres/rock/rock.00076.wav
# ../Final_report/gtzan_training/genres/rock/rock.00004.wav
# ../Final_report/gtzan_training/genres/rock/rock.00080.wav
# ../Final_report/gtzan_training/genres/rock/rock.00064.wav
# ../Final_report/gtzan_training/genres/rock/rock.00046.wav
# ../Final_report/gtzan_training/genres/rock/rock.00059.wav
# ../Final_report/gtzan_training/genres/rock/rock.00042.wav
# ../Final_report/gtzan_training/genres/rock/rock.00060.wav
# ../Final_report/gtzan_training/genres/rock/rock.00025.wav
# ../Final_report/gtzan_training/genres/rock/rock.00017.wav

# %%
X = np.load('x_gtzan_npy_v6.npy')
y = np.load('y_gtzan_npy_v6.npy')

# %%
# One hot encoding of the labels
y = to_categorical(y)

# %% [markdown]
# # Dataset Split

# %%
X_stack = np.squeeze(np.stack((X,) * 3, -1))
X_stack.shape
# Out:
# (8550, 128, 129, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_stack, y, test_size=0.1, random_state=42, stratify = y)

# %%
# Histogram for train and test 
values, count = np.unique(np.argmax(y_train, axis=1), return_counts=True)
plt.bar(values, count)

values, count = np.unique(np.argmax(y_test, axis=1), return_counts=True)
plt.bar(values, count)
plt.show()

# %% [markdown]
# # Training

# %%
# Model Definition
input_shape = X_train[0].shape
num_genres = 10

def cnn_vgg16(input_shape, num_genres, freezed_layers):
    input_tensor = Input(shape=input_shape)
    vgg16 = VGG16(include_top=False, weights='imagenet',
                  input_tensor=input_tensor)

    top = Sequential()
    top.add(Flatten(input_shape=vgg16.output_shape[1:]))
    top.add(Dense(256, activation='relu'))
    top.add(Dropout(0.5))
    top.add(Dense(num_genres, activation='softmax'))

    model = Model(inputs=vgg16.input, outputs=top(vgg16.output))
    for layer in model.layers[:freezed_layers]:
        layer.trainable = False

    return model

model = cnn_vgg16(input_shape, num_genres, 5)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 129, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 129, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 129, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 10)                2099978
# =================================================================
# Total params: 16,814,666
# Trainable params: 16,702,090
# Non-trainable params: 112,576
# _________________________________________________________________

# %%
model_path = '../Final_report/models/nbs_vgg16_v6.h5'

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)
batch_size = 128
epochs = 30

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

hist = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test, y_test),
          callbacks = [checkpoint, earlystop])
# Out:
# Train on 7695 samples, validate on 855 samples
# Epoch 1/30
# 7695/7695 [==============================] - 18s 2ms/step - loss: 1.8191 - acc: 0.3832 - val_loss: 1.2123 - val_acc: 0.4526
#
# Epoch 00001: val_loss improved from inf to 1.21227, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 2/30
# 7695/7695 [==============================] - 13s 2ms/step - loss: 1.0517 - acc: 0.5686 - val_loss: 0.7973 - val_acc: 0.7006
#
# Epoch 00002: val_loss improved from 1.21227 to 0.79730, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 3/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.8552 - acc: 0.6680 - val_loss: 0.7073 - val_acc: 0.7345
#
# Epoch 00003: val_loss improved from 0.79730 to 0.70726, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 4/30
# 7695/7695 [==============================] - 13s 2ms/step - loss: 0.7668 - acc: 0.7129 - val_loss: 0.9459 - val_acc: 0.5778
#
# Epoch 00004: val_loss did not improve from 0.70726
# Epoch 5/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.7046 - acc: 0.7352 - val_loss: 0.8380 - val_acc: 0.7041
#
# Epoch 00005: val_loss did not improve from 0.70726
# Epoch 6/30
# 7695/7695 [==============================] - 13s 2ms/step - loss: 0.6647 - acc: 0.7532 - val_loss: 0.6691 - val_acc: 0.7614
#
# Epoch 00006: val_loss improved from 0.70726 to 0.66915, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 7/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.5390 - acc: 0.8101 - val_loss: 0.5179 - val_acc: 0.8070
#
# Epoch 00007: val_loss improved from 0.66915 to 0.51792, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 8/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.4594 - acc: 0.8438 - val_loss: 0.6924 - val_acc: 0.7801
#
# Epoch 00008: val_loss did not improve from 0.51792
# Epoch 9/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.4365 - acc: 0.8521 - val_loss: 1.4904 - val_acc: 0.5860
#
# Epoch 00009: val_loss did not improve from 0.51792
# Epoch 10/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.5896 - acc: 0.7841 - val_loss: 0.4748 - val_acc: 0.8409
#
# Epoch 00010: val_loss improved from 0.51792 to 0.47480, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 11/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.4030 - acc: 0.8626 - val_loss: 0.4024 - val_acc: 0.8620
#
# Epoch 00011: val_loss improved from 0.47480 to 0.40240, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 12/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.3423 - acc: 0.8855 - val_loss: 0.2515 - val_acc: 0.9029
#
# Epoch 00012: val_loss improved from 0.40240 to 0.25149, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 13/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.3022 - acc: 0.8962 - val_loss: 0.2520 - val_acc: 0.9064
#
# Epoch 00013: val_loss did not improve from 0.25149
# Epoch 14/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.2470 - acc: 0.9211 - val_loss: 0.7094 - val_acc: 0.7497
#
# Epoch 00014: val_loss did not improve from 0.25149
# Epoch 15/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.4176 - acc: 0.8558 - val_loss: 0.3458 - val_acc: 0.8924
#
# Epoch 00015: val_loss did not improve from 0.25149
# Epoch 16/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.2251 - acc: 0.9245 - val_loss: 0.2192 - val_acc: 0.9228
#
# Epoch 00016: val_loss improved from 0.25149 to 0.21917, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 17/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1849 - acc: 0.9384 - val_loss: 0.1837 - val_acc: 0.9357
#
# Epoch 00017: val_loss improved from 0.21917 to 0.18370, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 18/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1471 - acc: 0.9485 - val_loss: 0.8425 - val_acc: 0.8117
#
# Epoch 00018: val_loss did not improve from 0.18370
# Epoch 19/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.2044 - acc: 0.9337 - val_loss: 0.1780 - val_acc: 0.9357
#
# Epoch 00019: val_loss improved from 0.18370 to 0.17800, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 20/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1531 - acc: 0.9484 - val_loss: 0.2072 - val_acc: 0.9240
#
# Epoch 00020: val_loss did not improve from 0.17800
# Epoch 21/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1210 - acc: 0.9600 - val_loss: 0.1773 - val_acc: 0.9275
#
# Epoch 00021: val_loss improved from 0.17800 to 0.17733, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 22/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.0986 - acc: 0.9678 - val_loss: 0.2063 - val_acc: 0.9345
#
# Epoch 00022: val_loss did not improve from 0.17733
# Epoch 23/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.0939 - acc: 0.9708 - val_loss: 0.1995 - val_acc: 0.9310
#
# Epoch 00023: val_loss did not improve from 0.17733
# Epoch 24/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1030 - acc: 0.9666 - val_loss: 0.2001 - val_acc: 0.9322
#
# Epoch 00024: val_loss did not improve from 0.17733
# Epoch 25/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1233 - acc: 0.9611 - val_loss: 0.1260 - val_acc: 0.9532
#
# Epoch 00025: val_loss improved from 0.17733 to 0.12595, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 26/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.0942 - acc: 0.9679 - val_loss: 0.1176 - val_acc: 0.9637
#
# Epoch 00026: val_loss improved from 0.12595 to 0.11759, saving model to ../Final_report/models/nbs_vgg16_v6.h5
# Epoch 27/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.0489 - acc: 0.9836 - val_loss: 0.1379 - val_acc: 0.9626
#
# Epoch 00027: val_loss did not improve from 0.11759
# Epoch 28/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.0913 - acc: 0.9714 - val_loss: 0.2141 - val_acc: 0.9298
#
# Epoch 00028: val_loss did not improve from 0.11759
# Epoch 29/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.1009 - acc: 0.9697 - val_loss: 0.1484 - val_acc: 0.9591
#
# Epoch 00029: val_loss did not improve from 0.11759
# Epoch 30/30
# 7695/7695 [==============================] - 14s 2ms/step - loss: 0.0431 - acc: 0.9869 - val_loss: 0.2018 - val_acc: 0.9298
#
# Epoch 00030: val_loss did not improve from 0.11759

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("val_loss = {:.3f} and val_acc = {:.3f}".format(score[0], score[1]))
# Out:
# val_loss = 0.202 and val_acc = 0.930

# %%
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.plot(hist.history['acc'], label='train')
plt.plot(hist.history['val_acc'], label='validation')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
preds = np.argmax(model.predict(X_test), axis = 1)
y_orig = np.argmax(y_test, axis = 1)
cm = confusion_matrix(preds, y_orig)

# %%
keys = OrderedDict(sorted(genres.items(), key=lambda t: t[1])).keys()

plt.figure(figsize=(8,8))
plot_confusion_matrix(cm, keys, normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## Save the model

# %%
# Save the model
# model.save('../Final_report/models/nbs_vgg16_v6.h5')

# %% [markdown]
# ## Test data process

# %%
#load model
model = load_model('../Final_report/models/nbs_vgg16_v6.h5')

# %%
# Parameters
# test_dir = '../Final_report/test_data'
test_dir = '../Final_report/gtzan_testing'
song_samples = 660000

# %%
def create_filename_list(src_dir):
    filename_list = []
    for root, subdirs, files in os.walk(src_dir):
        for file in files:
            filename_list.append(file)
    return filename_list

# %%
def read_test_data(src_dir, song_samples, spec_format):
    arr_specs = []
    music_splits_len = []
    
    for root, subdirs, files in os.walk(src_dir):
        for file in files:
            file_name = src_dir + "/" + file
            signal, sr = librosa.load(file_name)
            
#             target_samples = signal.shape[0] - (signal.shape[0] % sr)
            signal = signal[:song_samples]
                        
            # Convert to dataset of spectograms/melspectograms
            signals = splitsongs_for_test(signal, music_splits_len)
                
            # Convert to "spec" representation
            specs = spec_format(signals)
                
            # Save files
            arr_specs.extend(specs)
    return np.array(arr_specs), music_splits_len

# %%
"""
@description: Method to split a song into multiple songs using overlapping windows
"""
def splitsongs_for_test(X, music_splits_len, window = 0.1, overlap = 0.5):
    # Empty lists to hold our results
    temp_X = []

    # Get the input song array size
    xshape = X.shape[0]
    chunk = int(xshape*window)
    offset = int(chunk*(1.-overlap))
    
    # Split the song and create new ones on windows
    spsong = [X[i:i+chunk] for i in range(0, xshape - chunk + offset, offset)]
    for s in spsong:
        temp_X.append(s)
    music_splits_len.append(len(temp_X))
    return np.array(temp_X)

# %%
test_x, music_splits_len = read_test_data(test_dir, song_samples, to_melspectrogram)

# %%
# Read the data
np.save('test_x_v6_npy.npy', test_x)

# %%
X_test = np.load('test_x_v6_npy.npy')

# %%
X_test_stack = np.squeeze(np.stack((X_test,) * 3, -1))

# %%
predict_result = model.predict(X_test_stack)

# %%
def group_predict_result(predict_result, music_splits_len):
    grouping_predict_result = []
    delete_result = predict_result
    for length in music_splits_len:
        temp_grouping = []
        for i in range(length):
            temp_grouping.append(delete_result[0])
            delete_result = np.delete(delete_result, [0], axis=0)
        grouping_predict_result.append(temp_grouping)
    return grouping_predict_result

# %%
def most_frequent(List): 
    counter = 0
    num = List[0]
    for i in List: 
        curr_frequency = List.count(i) 
        if(curr_frequency> counter): 
            counter = curr_frequency 
            num = i
    return num

# %%
def get_predict_result(grouping_predict):
    final_result = []
    for group in grouping_predict:
        group_indexs = []
        for item in group:
            max = np.argmax(item, axis=0)
            group_indexs.append(max.tolist())
        max_duplicated_value = most_frequent(group_indexs)
        final_result.append(max_duplicated_value)
    return final_result

# %%
grouping_predict = group_predict_result(predict_result, music_splits_len)

# %%
final_predict = get_predict_result(grouping_predict)

# %%
filename_list = create_filename_list(test_dir)

# %%
predict = pd.DataFrame({"id":filename_list, "class":final_predict})

# %%
predict.to_csv("v6_submission.csv", index = False)

# %%
predict
# Out:
#                      id  class
# 0        jazz.00098.wav      4
# 1       blues.00092.wav      7
# 2   classical.00095.wav      2
# 3   classical.00096.wav      2
# 4       blues.00093.wav      7
# 5      hiphop.00099.wav      3
# 6   classical.00098.wav      2
# 7        rock.00091.wav      9
# 8   classical.00099.wav      2
# 9        jazz.00095.wav      4
# 10      blues.00090.wav      7
# 11     hiphop.00095.wav      3
# 12      blues.00091.wav      7
# 13       jazz.00097.wav      4
# 14       jazz.00090.wav      4
# 15       rock.00094.wav      9
# 16     hiphop.00096.wav      3
# 17       rock.00097.wav      9
# 18     hiphop.00097.wav      3
# 19       rock.00099.wav      9
# 20       jazz.00096.wav      4
# 21  classical.00093.wav      2
# 22      blues.00095.wav      7
# 23  classical.00092.wav      2
# 24     hiphop.00090.wav      3
# 25       jazz.00091.wav      4
# 26       rock.00092.wav      9
# 27     hiphop.00098.wav      3
# 28       jazz.00099.wav      4
# 29  classical.00091.wav      2
# 30       rock.00093.wav      9
# 31       jazz.00092.wav      4
# 32  classical.00094.wav      2
# 33     hiphop.00094.wav      3
# 34  classical.00090.wav      2
# 35  classical.00097.wav      2
# 36       jazz.00094.wav      4
# 37      blues.00097.wav      7
# 38      blues.00096.wav      2
# 39       rock.00098.wav      9
# 40       rock.00090.wav      7
# 41     hiphop.00091.wav      3
# 42       rock.00096.wav      9
# 43     hiphop.00092.wav      3
# 44      blues.00099.wav      9
# 45     hiphop.00093.wav      3
# 46      blues.00094.wav      7
# 47       rock.00095.wav      9
# 48       jazz.00093.wav      9
# 49      blues.00098.wav      9

# %%
genres = {'classical': 2, 'hiphop': 3, 'jazz': 4, 'blues': 7, 'rock': 9}

# %%
def getLables():
    labels = []
    for filename in filename_list:
        str_list = filename.split('.')
        labels.append(str_list[0])
    return labels

# %%
labels = getLables()

# %%
solution = pd.DataFrame({"id":filename_list, "class":labels})

# %%
mapping = genres

# %%
solution['class'] = solution['class'].map(mapping)

# %%
total_count = len(solution['class'])

# %%
def caculate_accuracy(total_count):
    correct = 0
    for i in range(total_count):
        print('==============================================================')
        print('solution index ' + str(i) + ' = ' + str(solution['class'][i]))
        print('predict index ' + str(i) + ' = ' + str(predict['class'][i]))
        if(solution['class'][i] == predict['class'][i]):
            print('predict correct')
            correct += 1
    return correct / total_count

# %%
caculate_accuracy(total_count)
# Out:
# ==============================================================
# solution index 0 = 4
# predict index 0 = 4
# predict correct
# ==============================================================
# solution index 1 = 7
# predict index 1 = 7
# predict correct
# ==============================================================
# solution index 2 = 2
# predict index 2 = 2
# predict correct
# ==============================================================
# solution index 3 = 2
# predict index 3 = 2
# predict correct
# ==============================================================
# solution index 4 = 7
# predict index 4 = 7
# predict correct
# ==============================================================
# solution index 5 = 3
# predict index 5 = 3
# predict correct
# ==============================================================
# solution index 6 = 2
# predict index 6 = 2
# predict correct
# ==============================================================
# solution index 7 = 9
# predict index 7 = 9
# predict correct
# ==============================================================
# solution index 8 = 2
# predict index 8 = 2
# predict correct
# ==============================================================
# solution index 9 = 4
# predict index 9 = 4
# predict correct
# ==============================================================
# solution index 10 = 7
# predict index 10 = 7
# predict correct
# ==============================================================
# solution index 11 = 3
# predict index 11 = 3
# predict correct
# ==============================================================
# solution index 12 = 7
# predict index 12 = 7
# predict correct
# ==============================================================
# solution index 13 = 4
# predict index 13 = 4
# predict correct
# ==============================================================
# solution index 14 = 4
# predict index 14 = 4
# predict correct
# ==============================================================
# solution index 15 = 9
# predict index 15 = 9
# predict correct
# ==============================================================
# solution index 16 = 3
# predict index 16 = 3
# predict correct
# ==============================================================
# solution index 17 = 9
# predict index 17 = 9
# predict correct
# ==============================================================
# solution index 18 = 3
# predict index 18 = 3
# predict correct
# ==============================================================
# solution index 19 = 9
# predict index 19 = 9
# predict correct
# ==============================================================
# solution index 20 = 4
# predict index 20 = 4
# predict correct
# ==============================================================
# solution index 21 = 2
# predict index 21 = 2
# predict correct
# ==============================================================
# solution index 22 = 7
# predict index 22 = 7
# predict correct
# ==============================================================
# solution index 23 = 2
# predict index 23 = 2
# predict correct
# ==============================================================
# solution index 24 = 3
# predict index 24 = 3
# predict correct
# ==============================================================
# solution index 25 = 4
# predict index 25 = 4
# predict correct
# ==============================================================
# solution index 26 = 9
# predict index 26 = 9
# predict correct
# ==============================================================
# solution index 27 = 3
# predict index 27 = 3
# predict correct
# ==============================================================
# solution index 28 = 4
# predict index 28 = 4
# predict correct
# ==============================================================
# solution index 29 = 2
# predict index 29 = 2
# predict correct
# ==============================================================
# solution index 30 = 9
# predict index 30 = 9
# predict correct
# ==============================================================
# solution index 31 = 4
# predict index 31 = 4
# predict correct
# ==============================================================
# solution index 32 = 2
# predict index 32 = 2
# predict correct
# ==============================================================
# solution index 33 = 3
# predict index 33 = 3
# predict correct
# ==============================================================
# solution index 34 = 2
# predict index 34 = 2
# predict correct
# ==============================================================
# solution index 35 = 2
# predict index 35 = 2
# predict correct
# ==============================================================
# solution index 36 = 4
# predict index 36 = 4
# predict correct
# ==============================================================
# solution index 37 = 7
# predict index 37 = 7
# predict correct
# ==============================================================
# solution index 38 = 7
# predict index 38 = 2
# ==============================================================
# solution index 39 = 9
# predict index 39 = 9
# predict correct
# ==============================================================
# solution index 40 = 9
# predict index 40 = 7
# ==============================================================
# solution index 41 = 3
# predict index 41 = 3
# predict correct
# ==============================================================
# solution index 42 = 9
# predict index 42 = 9
# predict correct
# ==============================================================
# solution index 43 = 3
# predict index 43 = 3
# predict correct
# ==============================================================
# solution index 44 = 7
# predict index 44 = 9
# ==============================================================
# solution index 45 = 3
# predict index 45 = 3
# predict correct
# ==============================================================
# solution index 46 = 7
# predict index 46 = 7
# predict correct
# ==============================================================
# solution index 47 = 9
# predict index 47 = 9
# predict correct
# ==============================================================
# solution index 48 = 4
# predict index 48 = 9
# ==============================================================
# solution index 49 = 7
# predict index 49 = 9
# 0.9

# %%
predict['ground_truth'] = solution['class']

# %%
predict
# Out:
#                      id  class  ground_truth
# 0        jazz.00098.wav      4             4
# 1       blues.00092.wav      7             7
# 2   classical.00095.wav      2             2
# 3   classical.00096.wav      2             2
# 4       blues.00093.wav      7             7
# 5      hiphop.00099.wav      3             3
# 6   classical.00098.wav      2             2
# 7        rock.00091.wav      9             9
# 8   classical.00099.wav      2             2
# 9        jazz.00095.wav      4             4
# 10      blues.00090.wav      7             7
# 11     hiphop.00095.wav      3             3
# 12      blues.00091.wav      7             7
# 13       jazz.00097.wav      4             4
# 14       jazz.00090.wav      4             4
# 15       rock.00094.wav      9             9
# 16     hiphop.00096.wav      3             3
# 17       rock.00097.wav      9             9
# 18     hiphop.00097.wav      3             3
# 19       rock.00099.wav      9             9
# 20       jazz.00096.wav      4             4
# 21  classical.00093.wav      2             2
# 22      blues.00095.wav      7             7
# 23  classical.00092.wav      2             2
# 24     hiphop.00090.wav      3             3
# 25       jazz.00091.wav      4             4
# 26       rock.00092.wav      9             9
# 27     hiphop.00098.wav      3             3
# 28       jazz.00099.wav      4             4
# 29  classical.00091.wav      2             2
# 30       rock.00093.wav      9             9
# 31       jazz.00092.wav      4             4
# 32  classical.00094.wav      2             2
# 33     hiphop.00094.wav      3             3
# 34  classical.00090.wav      2             2
# 35  classical.00097.wav      2             2
# 36       jazz.00094.wav      4             4
# 37      blues.00097.wav      7             7
# 38      blues.00096.wav      2             7
# 39       rock.00098.wav      9             9
# 40       rock.00090.wav      7             9
# 41     hiphop.00091.wav      3             3
# 42       rock.00096.wav      9             9
# 43     hiphop.00092.wav      3             3
# 44      blues.00099.wav      9             7
# 45     hiphop.00093.wav      3             3
# 46      blues.00094.wav      7             7
# 47       rock.00095.wav      9             9
# 48       jazz.00093.wav      9             4
# 49      blues.00098.wav      9             7

# %%
def get_predict_list():
    predict_list = []
    for i in range(total_count):
        predict_result = False
        if(solution['class'][i] == predict['class'][i]):
            predict_result = True
        predict_list.append(predict_result)
    return predict_list

# %%
predict['predict_correct'] = get_predict_list()

# %%
predict
# Out:
#                      id  class  ground_truth  predict_result  predict_correct
# 0        jazz.00098.wav      4             4            True             True
# 1       blues.00092.wav      7             7            True             True
# 2   classical.00095.wav      2             2            True             True
# 3   classical.00096.wav      2             2            True             True
# 4       blues.00093.wav      7             7            True             True
# 5      hiphop.00099.wav      3             3            True             True
# 6   classical.00098.wav      2             2            True             True
# 7        rock.00091.wav      9             9            True             True
# 8   classical.00099.wav      2             2            True             True
# 9        jazz.00095.wav      4             4            True             True
# 10      blues.00090.wav      7             7            True             True
# 11     hiphop.00095.wav      3             3            True             True
# 12      blues.00091.wav      7             7            True             True
# 13       jazz.00097.wav      4             4            True             True
# 14       jazz.00090.wav      4             4            True             True
# 15       rock.00094.wav      9             9            True             True
# 16     hiphop.00096.wav      3             3            True             True
# 17       rock.00097.wav      9             9            True             True
# 18     hiphop.00097.wav      3             3            True             True
# 19       rock.00099.wav      9             9            True             True
# 20       jazz.00096.wav      4             4            True             True
# 21  classical.00093.wav      2             2            True             True
# 22      blues.00095.wav      7             7            True             True
# 23  classical.00092.wav      2             2            True             True
# 24     hiphop.00090.wav      3             3            True             True
# 25       jazz.00091.wav      4             4            True             True
# 26       rock.00092.wav      9             9            True             True
# 27     hiphop.00098.wav      3             3            True             True
# 28       jazz.00099.wav      4             4            True             True
# 29  classical.00091.wav      2             2            True             True
# 30       rock.00093.wav      9             9            True             True
# 31       jazz.00092.wav      4             4            True             True
# 32  classical.00094.wav      2             2            True             True
# 33     hiphop.00094.wav      3             3            True             True
# 34  classical.00090.wav      2             2            True             True
# 35  classical.00097.wav      2             2            True             True
# 36       jazz.00094.wav      4             4            True             True
# 37      blues.00097.wav      7             7            True             True
# 38      blues.00096.wav      2             7           False            False
# 39       rock.00098.wav      9             9            True             True
# 40       rock.00090.wav      7             9           False            False
# 41     hiphop.00091.wav      3             3            True             True
# 42       rock.00096.wav      9             9            True             True
# 43     hiphop.00092.wav      3             3            True             True
# 44      blues.00099.wav      9             7           False            False
# 45     hiphop.00093.wav      3             3            True             True
# 46      blues.00094.wav      7             7            True             True
# 47       rock.00095.wav      9             9            True             True
# 48       jazz.00093.wav      9             4           False            False
# 49      blues.00098.wav      9             7           False            False

# %%
predict.to_csv("predict_result.csv", index = False)
